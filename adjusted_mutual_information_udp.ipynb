# %% [markdown]
# # Feature Selection using the Adjusted Mutual Information (AMI) Score
#
# ### (UDP analysis only)
#
# This notebook uses the Adjusted Mutual Information Score to determine the most relevant features in the DDoS attacks. It uses the bigflows pcap from [http://tcpreplay.appneta.com/wiki/captures.html] containing normal network traffic. The DDoS attack pcaps from DDoSDB [https://ddosdb.org/] are used to compare it with the normal network traffic.

# %%
#all relevant libraries need to be imported
from sklearn.metrics.cluster import adjusted_mutual_info_score, mutual_info_score, normalized_mutual_info_score
from sklearn.feature_selection import mutual_info_classif
import numpy as np
import dpkt
import Utils
import ipaddress
import pandas as pd
import time
import os
import json
import operator

# %% [markdown]
# ### Load bigflows containing only UDP traffic

# %%
start = time.time()

input = open('normal_pcaps/bigflows_udp.pcap', 'rb')
normal = dpkt.pcap.Reader(input)
length = 152733 #this is the number of packets in bigflows_udp.pcap   #791615 #791179

ips_n = np.empty(length)
protocol_n = np.empty(length)
total_length_n = np.empty(length)
src_port_n = np.empty(length)
dst_port_n = np.empty(length)
udp_length_n = np.empty(length)
labels_n = np.zeros(length)

udp_packet = 0
tcp_packet = 0
other = 0
total_packet = 0
 
i=0
for ts, buf in normal:
    eth = dpkt.ethernet.Ethernet(buf)
    total_packet += 1 

    if eth.type == 2048:
        ip = eth.data
        ips_n[i] = int.from_bytes(ip.src,"little")
        protocol_n[i] = ip.p
        total_length_n[i] = ip.len
        
        if ip.p == 6:
            tcp_packet += 1
            TCP=ip.data 
            dst_port_n[i] = TCP.dport
            src_port_n[i] = TCP.sport
        elif ip.p == 17:
            udp_packet += 1
            UDP=ip.data
            dst_port_n[i] = UDP.dport
            src_port_n[i] = UDP.sport
            udp_length_n[i] = UDP.ulen
        else:
            dst_port_n[i] = 0
            src_port_n[i] = 0
    else:
        other += 1
        
    i += 1

input.close()
print("total # of packets: %s"  % (total_packet))
print("# of UDP packets: %s" % (udp_packet))
print("# of TCP packets: %s" % (tcp_packet))
print("# of other packets except for TCP or UDP: %s"  % (other))

end = time.time()
print(end - start)
# Out:
# total # of packets: 152733
# # of UDP packets: 152733
# # of TCP packets: 0
# # of other packets except for TCP or UDP: 0
# 2.6143155097961426

# %% [markdown]
# ### Get attack keys of DDoS attacks containing only UDP traffic

# %%
path_to_json = 'signatures/'
json_files = [pos_json for pos_json in os.listdir(path_to_json) if pos_json.endswith('.json')]

udp_keys=[]

for jf in json_files:
    with open('signatures/' + jf) as f:
        data=json.load(f)
    protocol = data.get("protocol")

    if protocol == "UDP":
        udp_keys.append(jf[:-5])

print("# of UDP DDoS attacks: ", len(udp_keys))
# Out:
# # of UDP DDoS attacks:  159

# %% [markdown]
# ### Get AMI score and other stats per UDP DDoS Attack

# %%
start = time.time()

counter = 1
most_important_features = []

#iterate over all attack keys with UDP attacks
for attack_key in udp_keys:
    try:
        input = open('attack_pcaps/' + attack_key + '.pcap', 'rb')
        attack = dpkt.pcap.Reader(input)

        udp_packet = 0
        tcp_packet = 0
        other = 0
        total_packet = 0
        i = 0
        
        ############### 
        #loop trough packets to get the number of packets in the attack
        #############
        for ts, buf in attack:
            eth = dpkt.ethernet.Ethernet(buf)
            total_packet += 1 

        input.close()
        
        #######################
        #initialize numpy arrays for all the to measure features
        ##############################
        ips_a = np.empty(total_packet)
        protocol_a = np.empty(total_packet)
        total_length_a = np.empty(total_packet)
        src_port_a = np.empty(total_packet)
        dst_port_a = np.empty(total_packet)
        udp_length_a = np.empty(total_packet)
        labels_a = np.ones(total_packet)    
        
        ###############
        #loop trough packets and gather features
        #########
        input = open('attack_pcaps/' + attack_key + '.pcap', 'rb')
        attack = dpkt.pcap.Reader(input)
        i = 0
        for ts, buf in attack:
            eth = dpkt.ethernet.Ethernet(buf)
            if eth.type == 2048:
                ip = eth.data
                ips_a[i] = int.from_bytes(ip.src,"little")
                protocol_a[i] = ip.p
                total_length_a[i] = ip.len

                if ip.p == 6:
                    tcp_packet += 1
                    TCP=ip.data 
                    dst_port_a[i] = TCP.dport
                    src_port_a[i] = TCP.sport
                elif ip.p == 17:
                    udp_packet += 1
                    UDP=ip.data
                    udp_length_a[i] = UDP.ulen
                    dst_port_a[i] = UDP.dport
                    src_port_a[i] = UDP.sport
                else:
                    other += 1
                    dst_port_a[i] = 0
                    src_port_a[i] = 0
            else:
                other += 1

            i += 1
            
        ###############
        #make Numpy arrays with attack features and normal features together
        ################
        ips = np.append(ips_a, ips_n)
        protocol = np.append(protocol_a, protocol_n)
        total_length = np.append(total_length_a, total_length_n)
        src_port = np.append(src_port_a, src_port_n)
        dst_port = np.append(dst_port_a, dst_port_n)
        udp_length = np.append(udp_length_a, udp_length_n)
        labels = np.append(labels_a, labels_n)

        features = [ips,protocol,total_length,src_port,dst_port,udp_length]

        
        ##########
        #Calculate adjusted mutual information score
        ############
        scores = []
        for x in features:
            score = adjusted_mutual_info_score(np.repeat(x,4), np.repeat(labels,4), "arithmetic")
            scores.append(score)
            
        ###########
        #Print all stats per attack
        #######
        print("attackkey: ", attack_key)
        print("total # of packets: %s"  % (total_packet))
        print("# of UDP packets: %s" % (udp_packet))
        print("# of TCP packets: %s" % (tcp_packet))
        print("# of other packets except for TCP or UDP: %s"  % (other))
        print("Features: ips,protocol,total_length,src_port,dst_port,udp_length")
        print("AMI scores: ", scores)
        
        max_index, max_value = max(enumerate(scores), key=operator.itemgetter(1))
        most_important_features.append(max_index)
        print("Most important feature: ", max_index)
        end = time.time()
        print(end - start)
        print(counter,"/",len(udp_keys))
        counter += 1
        print("#####################################")
    except:
        print("something went wrong with attack ", attack_key)
print(end - start)
# Out:
# attackkey:  a3e78a6e687223edf712320712686ab2
# total # of packets: 247
# # of UDP packets: 247
# # of TCP packets: 0
# # of other packets except for TCP or UDP: 0
# Features: ips,protocol,total_length,src_port,dst_port,udp_length
# AMI scores:  [0.006548274996752432, 8.869476593269325e-13, 0.006570755099051521, 0.0083814682667021, 0.007996524118674544, 0.006571443148166646]
# Most important feature:  3
# 1.3508050441741943
# 1 / 159
# #####################################
# attackkey:  af254ac963139fc85e9a42ceaabc91d6
# total # of packets: 475
# # of UDP packets: 475
# # of TCP packets: 0
# # of other packets except for TCP or UDP: 0
# Features: ips,protocol,total_length,src_port,dst_port,udp_length
# AMI scores:  [0.011468554019273255, 5.058903570033307e-13, 0.013082023237447902, 0.014653962661291023, 0.01387406720611379, 0.013083262731725696]
# Most important feature:  3
# 2.7843987941741943
# 2 / 159
# #####################################
# attackkey:  f686ce6cfb9e038f7071e080228698d2
# total # of packets: 219
# # of UDP packets: 127
# # of TCP packets: 0
# # of other packets except for TCP or UDP: 92
# Features: ips,protocol,total_length,src_port,dst_port,udp_length
# AMI scores:  [0.005903740120026497, 0.5151437596962095, 0.005914106321576718, 0.007549881085901638, 0.007223614587866637, 0.006637473239259922]
# Most important feature:  1
# 4.137835741043091
# 3 / 159
# #####################################
# attackkey:  83612b86275de6b6d624f04e310fb903
# total # of packets: 294
# # of UDP packets: 192
# # of TCP packets: 0
# # of other packets except for TCP or UDP: 102
# Features: ips,protocol,total_length,src_port,dst_port,udp_length
# AMI scores:  [0.007612242930119454, 0.44157405164495306, 0.007358591065456327, 0.009732958738621131, 0.009316227963204003, 0.008360505294489127]
# Most important feature:  1
# 5.484957456588745
# 4 / 159
# #####################################
# something went wrong with attack  17172f1765db1df8162e6083e79a7f05
# attackkey:  dd970144d10760adef141d956a60d401
# total # of packets: 826541
# # of UDP packets: 812236
# # of TCP packets: 0
# # of other packets except for TCP or UDP: 14305
# Features: ips,protocol,total_length,src_port,dst_port,udp_length
# AMI scores:  [0.14725239675617582, 0.009807319888313123, 0.08424453634431964, 0.627595206934006, 0.6230042189161216, 0.08437123493153047]
# Most important feature:  3
# 50.917728900909424
# 5 / 159
# #####################################
# attackkey:  f17db0d141a535c1b18d70cbfe13a6a5
# total # of packets: 668
# # of UDP packets: 668
# # of TCP packets: 0
# # of other packets except for TCP or UDP: 0
# Features: ips,protocol,total_length,src_port,dst_port,udp_length
# AMI scores:  [0.015246102752482954, 3.7922375180129394e-13, 0.01877657310435422, 0.019504890085221407, 0.01818651815483918, 0.018778303893255608]
# Most important feature:  3
# 52.39254188537598
# 6 / 159
# #####################################
# attackkey:  730279c40f615bb3d6957a6182043425
# total # of packets: 771
# # of UDP packets: 771
# # of TCP packets: 0
# # of other packets except for TCP or UDP: 0
# Features: ips,protocol,total_length,src_port,dst_port,udp_length
# AMI scores:  [0.017191501527372633, 1.7881854872253234e-15, 0.018683524329055737, 0.02196933760823431, 0.020629102145823117, 0.018685232739217964]
# Most important feature:  3
# 53.862375020980835
# 7 / 159
# #####################################
# attackkey:  e75f94a6a5b6afb05b20872800a6db97
# total # of packets: 413405
# # of UDP packets: 374547
# # of TCP packets: 0
# # of other packets except for TCP or UDP: 38858
# Features: ips,protocol,total_length,src_port,dst_port,udp_length
# AMI scores:  [0.16761765734091616, 0.054013737226494704, 0.12138276840091144, 0.5375998754896356, 0.5366155410208133, 0.12502333798594636]
# Most important feature:  3
# 77.64582753181458
# 8 / 159
# #####################################
# attackkey:  b31fef7a664bc7101a0754852a977026
# total # of packets: 491
# # of UDP packets: 491
# # of TCP packets: 0
# # of other packets except for TCP or UDP: 0
# Features: ips,protocol,total_length,src_port,dst_port,udp_length
# AMI scores:  [0.01177910801922074, 3.2119741934460375e-16, 0.015165764773677924, 0.015069465082749561, 0.014129539062948627, 0.015167195264899506]
# Most important feature:  5
# 79.0641086101532
# 9 / 159
# #####################################
# attackkey:  13073741f538935aa8adfe90bad2ed52
# total # of packets: 8
# # of UDP packets: 8
# # of TCP packets: 0
# # of other packets except for TCP or UDP: 0
# Features: ips,protocol,total_length,src_port,dst_port,udp_length
# AMI scores:  [0.0002905725619100433, -6.2483243833916365e-12, 0.00014634969818396772, 0.0003756157311691188, 0.0003631745681692594, 0.0001463730632482749]
# Most important feature:  3
# 80.29505324363708
# 10 / 159
# #####################################
# attackkey:  07047eb879829a0f00ba03fa1425a2ae
# total # of packets: 371
# # of UDP packets: 371
# # of TCP packets: 0
# # of other packets except for TCP or UDP: 0
# Features: ips,protocol,total_length,src_port,dst_port,udp_length
# AMI scores:  [0.00928783761362904, 2.0809353189989597e-13, 0.010956305555818138, 0.011882359287819803, 0.011158954958442617, 0.010957374070569004]
# Most important feature:  3
# 81.85587239265442
# 11 / 159
# #####################################
# attackkey:  a1cb072097c76dc0ccd86bf0f27e4ea6
# total # of packets: 5332
# # of UDP packets: 5332
# # of TCP packets: 0
# # of other packets except for TCP or UDP: 0
# Features: ips,protocol,total_length,src_port,dst_port,udp_length
# AMI scores:  [0.07482507344490641, 7.073346016530701e-14, 0.10563815732952193, 0.0980641671974794, 0.0866236989703807, 0.1056469247154188]
# Most important feature:  5
# 83.80318689346313
# 12 / 159
# #####################################
# attackkey:  fc81d769d7832fa40a4cda6ae7877e8b
# total # of packets: 8
# # of UDP packets: 8
# # of TCP packets: 0
# # of other packets except for TCP or UDP: 0
# Features: ips,protocol,total_length,src_port,dst_port,udp_length
# AMI scores:  [0.0002905725619100433, -6.2483243833916365e-12, 0.00014634969818396772, 0.00037314791674140316, 0.00036317456816925943, 0.0001463730632482749]
# Most important feature:  3
# 85.16131687164307
# 13 / 159
# #####################################
# attackkey:  d73d0246981dde6351ef6e9d3085dab5
# total # of packets: 908
# # of UDP packets: 908
# # of TCP packets: 0
# # of other packets except for TCP or UDP: 0
# Features: ips,protocol,total_length,src_port,dst_port,udp_length
# AMI scores:  [0.01955225262898378, 0.0, 0.022523309583928168, 0.02513696755557156, 0.023752568630289118, 0.022525359234225485]
# Most important feature:  3
# 86.76504802703857
# 14 / 159
# #####################################
# attackkey:  9138ab0055963f033fd015cea2ef1bc6
# total # of packets: 343
# # of UDP packets: 343
# # of TCP packets: 0
# # of other packets except for TCP or UDP: 0
# Features: ips,protocol,total_length,src_port,dst_port,udp_length
# AMI scores:  [0.008693403790725975, -4.3616898723708793e-16, 0.010937318023727325, 0.01111271033289334, 0.010512999474658813, 0.01093839228377975]
# Most important feature:  3
# 88.19661855697632
# 15 / 159
# #####################################
# attackkey:  9f2d134c9d1f77d377420946b382ca9c
# total # of packets: 338
# # of UDP packets: 338
# # of TCP packets: 0
# # of other packets except for TCP or UDP: 0
# Features: ips,protocol,total_length,src_port,dst_port,udp_length
# AMI scores:  [0.008578783324186318, 2.2084709851565823e-16, 0.01085793695885449, 0.010974103543643707, 0.010398135226850742, 0.010859004734630149]
# Most important feature:  3
# 89.61128783226013
# 16 / 159
# #####################################
# attackkey:  20951de69e85a3917bd2606e6fea77f9
# total # of packets: 8
# # of UDP packets: 8
# # of TCP packets: 0
# # of other packets except for TCP or UDP: 0
# Features: ips,protocol,total_length,src_port,dst_port,udp_length
# AMI scores:  [0.0002905725619100433, -6.2483243833916365e-12, 0.00014634969818396772, 0.00038215389426998335, 0.0003631745681692594, 0.0001463730632482749]
# Most important feature:  3
# 90.86725115776062
# 17 / 159
# #####################################
# attackkey:  d96e85c5f1b3b208c4f53b95abb4aa4a
# total # of packets: 0
# # of UDP packets: 0
# # of TCP packets: 0
# # of other packets except for TCP or UDP: 0
# Features: ips,protocol,total_length,src_port,dst_port,udp_length
# AMI scores:  [5.953951761378233e-16, 1.0, 7.669834934216181e-16, 2.0484401348601635e-15, 8.803657203244096e-16, 7.692973660975005e-16]
# Most important feature:  1
# 91.9615912437439
# 18 / 159
# #####################################
# attackkey:  967a3709db351926be99ddc0f7d4697a
# total # of packets: 681
# # of UDP packets: 681
# # of TCP packets: 0
# # of other packets except for TCP or UDP: 0
# Features: ips,protocol,total_length,src_port,dst_port,udp_length
# AMI scores:  [0.015501244594714494, -2.4367108534375903e-16, 0.017702573596698228, 0.019820242198163147, 0.01874812023426459, 0.017704201729856418]
# Most important feature:  3
# 93.43812656402588
# 19 / 159
# #####################################
# attackkey:  7f19b44817e1d16ea99933c6bce54131
# total # of packets: 66618
# # of UDP packets: 66618
# # of TCP packets: 0
# # of other packets except for TCP or UDP: 0
# Features: ips,protocol,total_length,src_port,dst_port,udp_length
# AMI scores:  [0.16167265044565451, 0.0, 0.4126516174331586, 0.1801784361694599, 0.37856030967213306, 0.4118634886988974]
# Most important feature:  2
# 99.2564013004303
# 20 / 159
# #####################################
# attackkey:  079c27d54c337110c12ae61ea3efe580
# total # of packets: 176
# # of UDP packets: 176
# # of TCP packets: 0
# # of other packets except for TCP or UDP: 0
# Features: ips,protocol,total_length,src_port,dst_port,udp_length
# AMI scores:  [0.004882659448307112, -1.9405423938635947e-16, 0.005518143500554982, 0.006246267024263329, 0.005948310759051495, 0.005518741673929008]
# Most important feature:  3
# 100.57915019989014
# 21 / 159
# #####################################
# attackkey:  cfb5e3087834c5a423727f1ae9ca47e7
# total # of packets: 777902
# # of UDP packets: 764024
# # of TCP packets: 0
# # of other packets except for TCP or UDP: 13878
# Features: ips,protocol,total_length,src_port,dst_port,udp_length
# AMI scores:  [0.1514724131513671, 0.010288139154250071, 0.08615984488548717, 0.6243873257255178, 0.6194290863087256, 0.0863567892590195]
# Most important feature:  3
# 140.3851501941681
# 22 / 159
# #####################################
# attackkey:  190d042270655400a9d60d6ca87aca0f
# total # of packets: 240
# # of UDP packets: 147
# # of TCP packets: 0
# # of other packets except for TCP or UDP: 93
# Features: ips,protocol,total_length,src_port,dst_port,udp_length
# AMI scores:  [0.006390771812904595, 0.4833274027691157, 0.005742510413636149, 0.00817222538283626, 0.0077785445705928795, 0.007104076606605384]
# Most important feature:  1
# 141.728777885437
# 23 / 159
# #####################################
# attackkey:  9ae4af2b74c64e5243e5ef791c9894ff
# total # of packets: 523
# # of UDP packets: 523
# # of TCP packets: 0
# # of other packets except for TCP or UDP: 0
# Features: ips,protocol,total_length,src_port,dst_port,udp_length
# AMI scores:  [0.01242196302982235, -6.089087475725221e-16, 0.014561076493713573, 0.015892611679172993, 0.014909468462862221, 0.014562443791289691]
# Most important feature:  3
# 143.12387418746948
# 24 / 159
# #####################################
# attackkey:  7f2b2ef41a396bbd0269a4801fd84274
# total # of packets: 308
# # of UDP packets: 308
# # of TCP packets: 0
# # of other packets except for TCP or UDP: 0
# Features: ips,protocol,total_length,src_port,dst_port,udp_length
# AMI scores:  [0.00791536267755652, 7.33085602733043e-13, 0.008780240712892939, 0.010134574599658339, 0.009686249433609543, 0.008781122117096635]
# Most important feature:  3
# 144.48428797721863
# 25 / 159
# #####################################
# attackkey:  700062ab3a066e721cc674c40a089795
# total # of packets: 1677
# # of UDP packets: 1677
# # of TCP packets: 0
# # of other packets except for TCP or UDP: 0
# Features: ips,protocol,total_length,src_port,dst_port,udp_length
# AMI scores:  [0.03232311149167387, -1.7510883865939518e-15, 0.04368480137979166, 0.0412027800451178, 0.03872076364030938, 0.04368870095646072]
# Most important feature:  5
# 146.08285307884216
# 26 / 159
# #####################################
# attackkey:  bf658bd4e4dbe9d31c125f531a3d27ab
# total # of packets: 370
# # of UDP packets: 370
# # of TCP packets: 0
# # of other packets except for TCP or UDP: 0
# Features: ips,protocol,total_length,src_port,dst_port,udp_length
# AMI scores:  [0.00925819364960157, -2.043846200980861e-16, 0.009594466315690706, 0.011855057860630062, 0.011293891483294302, 0.009595408469269808]
# Most important feature:  3
# 147.54157543182373
# 27 / 159
# #####################################
# attackkey:  9b87222053c383934c1347e45f383701
# total # of packets: 356
# # of UDP packets: 356
# # of TCP packets: 0
# # of other packets except for TCP or UDP: 0
# Features: ips,protocol,total_length,src_port,dst_port,udp_length
# AMI scores:  [0.008966206732296953, 2.1541622016095764e-13, 0.010691631465787412, 0.011471407373510755, 0.010825552763172585, 0.010692678780877422]
# Most important feature:  3
# 149.15565729141235
# 28 / 159
# #####################################
# attackkey:  00631e77cb5c08e9d5e7673a73bcd887
# total # of packets: 123
# # of UDP packets: 123
# # of TCP packets: 0
# # of other packets except for TCP or UDP: 0
# Features: ips,protocol,total_length,src_port,dst_port,udp_length
# AMI scores:  [0.0035633460983553367, -2.653396695061785e-16, 0.004004102112231152, 0.004564154881552469, 0.004303524797580013, 0.004004555253944771]
# Most important feature:  3
# 150.63167715072632
# 29 / 159
# #####################################
# attackkey:  bd3dd0d241ed5dafb0837c557ffeb3c3
# total # of packets: 182
# # of UDP packets: 182
# # of TCP packets: 0
# # of other packets except for TCP or UDP: 0
# Features: ips,protocol,total_length,src_port,dst_port,udp_length
# AMI scores:  [0.005025401514499311, 1.1566613583935849e-12, 0.005606800272477525, 0.00643139355637857, 0.006005654662703044, 0.0056074064125474716]
# Most important feature:  3
# 152.03389024734497
# 30 / 159
# #####################################
# attackkey:  a89b7e2b2c68423fb5a2cd59bb938ea8
# total # of packets: 961411
# # of UDP packets: 912684
# # of TCP packets: 0
# # of other packets except for TCP or UDP: 48727
# Features: ips,protocol,total_length,src_port,dst_port,udp_length
# AMI scores:  [0.11126213937969952, 0.02280452452199892, 0.07693310113009333, 0.5906383356035537, 0.07212958316950517, 0.07746626311463009]
# Most important feature:  3
# 208.15427350997925
# 31 / 159
# #####################################
# attackkey:  d442035488dd227043575c4008fb4aba
# total # of packets: 105
# # of UDP packets: 54
# # of TCP packets: 0
# # of other packets except for TCP or UDP: 51
# Features: ips,protocol,total_length,src_port,dst_port,udp_length
# AMI scores:  [0.003098865465325732, 0.5816496747800945, 0.00260356913059753, 0.003969251130134688, 0.003776117569990502, 0.00329320072299899]
# Most important feature:  1
# 209.58411407470703
# 32 / 159
# #####################################
# attackkey:  b0bed1288522fdc2bffea0396ba00084
# total # of packets: 157
# # of UDP packets: 157
# # of TCP packets: 0
# # of other packets except for TCP or UDP: 0
# Features: ips,protocol,total_length,src_port,dst_port,udp_length
# AMI scores:  [0.00441805578095483, -1.5447027196813102e-15, 0.00511686896775906, 0.005653409397764146, 0.0053260102120858245, 0.005117429782172987]
# Most important feature:  3
# 210.98642492294312
# 33 / 159
# #####################################
# attackkey:  e6835a1145558209507d89dcf5cdfae8
# total # of packets: 5322
# # of UDP packets: 5322
# # of TCP packets: 0
# # of other packets except for TCP or UDP: 0
# Features: ips,protocol,total_length,src_port,dst_port,udp_length
# AMI scores:  [0.07469861838824744, -7.538037420110852e-16, 0.10550328780325802, 0.09793493405467632, 0.08609640245313484, 0.10551204562457392]
# Most important feature:  5
# 212.93332409858704
# 34 / 159
# #####################################
# attackkey:  fd06f0fb58e60cf868de83b5ab6fc350
# total # of packets: 159
# # of UDP packets: 159
# # of TCP packets: 0
# # of other packets except for TCP or UDP: 0
# Features: ips,protocol,total_length,src_port,dst_port,udp_length
# AMI scores:  [0.004466053045564597, -1.3270859109890146e-15, 0.0052568304879922825, 0.005716310605718178, 0.005385439617611951, 0.00525740440786738]
# Most important feature:  3
# 214.26876282691956
# 35 / 159
# #####################################
# attackkey:  7be5d0b068e5df261431496286c1e86f
# total # of packets: 124
# # of UDP packets: 124
# # of TCP packets: 0
# # of other packets except for TCP or UDP: 0
# Features: ips,protocol,total_length,src_port,dst_port,udp_length
# AMI scores:  [0.0035907824590328203, 1.6658143999416647e-15, 0.0038915842120837694, 0.004596773948988136, 0.004355836440068449, 0.0038920270772152465]
# Most important feature:  3
# 215.5625295639038
# 36 / 159
# #####################################
# attackkey:  e6c3668c7cd00f4b287b6fc92a0afcb9
# total # of packets: 319
# # of UDP packets: 319
# # of TCP packets: 0
# # of other packets except for TCP or UDP: 0
# Features: ips,protocol,total_length,src_port,dst_port,udp_length
# AMI scores:  [0.008168936358077167, 7.117474725007162e-13, 0.010208246371887325, 0.010444008460021506, 0.009869985129128976, 0.010209258671937756]
# Most important feature:  3
# 217.00736331939697
# 37 / 159
# #####################################
# attackkey:  acc4394329ad248f5e77c165804a0bc6
# total # of packets: 98
# # of UDP packets: 98
# # of TCP packets: 0
# # of other packets except for TCP or UDP: 0
# Features: ips,protocol,total_length,src_port,dst_port,udp_length
# AMI scores:  [0.0029154746380653644, 6.629798910045078e-13, 0.0031999559775679038, 0.0037353306096356243, 0.003503529972764894, 0.003200327752157312]
# Most important feature:  3
# 218.3472306728363
# 38 / 159
# #####################################
# attackkey:  ae87f4dbbd8c4ccc941995ff673e29b0
# total # of packets: 494
# # of UDP packets: 494
# # of TCP packets: 0
# # of other packets except for TCP or UDP: 0
# Features: ips,protocol,total_length,src_port,dst_port,udp_length
# AMI scores:  [0.0118361376847887, 4.89241319709741e-13, 0.014253671690405747, 0.015147074842576139, 0.014225361294022472, 0.0142550173236614]
# Most important feature:  3
# 219.74582433700562
# 39 / 159
# #####################################
# attackkey:  d3d5d8c57ffd4dd8bbf51cdf0f46e5ef
# total # of packets: 842
# # of UDP packets: 842
# # of TCP packets: 0
# # of other packets except for TCP or UDP: 0
# Features: ips,protocol,total_length,src_port,dst_port,udp_length
# AMI scores:  [0.01848516061783338, 3.116135774104373e-13, 0.021430856365263137, 0.023625626833782727, 0.022328820713827118, 0.021432809173469302]
# Most important feature:  3
# 221.26381540298462
# 40 / 159
# #####################################
# attackkey:  da27a3365d19888db6a6e3be0b29e669
# total # of packets: 544
# # of UDP packets: 544
# # of TCP packets: 0
# # of other packets except for TCP or UDP: 0
# Features: ips,protocol,total_length,src_port,dst_port,udp_length
# AMI scores:  [0.012839614927554852, 1.4962982640940657e-13, 0.015725710347998915, 0.016427343596577958, 0.015415058669390564, 0.015727180948097864]
# Most important feature:  3
# 222.6617305278778
# 41 / 159
# #####################################
# attackkey:  4438d16f17dbe7e31d69305dd7892080
# total # of packets: 81
# # of UDP packets: 47
# # of TCP packets: 0
# # of other packets except for TCP or UDP: 34
# Features: ips,protocol,total_length,src_port,dst_port,udp_length
# AMI scores:  [0.0024602276041783685, 0.5234549944186431, 0.0023195681754950713, 0.003154443097687006, 0.0030104655770691467, 0.0027223021679098104]
# Most important feature:  1
# 223.9767608642578
# 42 / 159
# #####################################
# attackkey:  921a0d65f7cb7b321862f7787d4986d6
# total # of packets: 126
# # of UDP packets: 70
# # of TCP packets: 0
# # of other packets except for TCP or UDP: 56
# Features: ips,protocol,total_length,src_port,dst_port,udp_length
# AMI scores:  [0.0036407153462962184, 0.5428092958018926, 0.003654859060152463, 0.004660677401344078, 0.004466790051403048, 0.004091210458697826]
# Most important feature:  1
# 225.2937421798706
# 43 / 159
# #####################################
# attackkey:  d5fc48e54ce98252f2c748728c34a25a
# total # of packets: 510
# # of UDP packets: 510
# # of TCP packets: 0
# # of other packets except for TCP or UDP: 0
# Features: ips,protocol,total_length,src_port,dst_port,udp_length
# AMI scores:  [0.012161651134134697, -4.767419053690027e-13, 0.015530149561406543, 0.015559444592875584, 0.014598211255673782, 0.015531610000164373]
# Most important feature:  3
# 226.84445524215698
# 44 / 159
# #####################################
# attackkey:  066e98334a23b2b6bd4d95d572fea817
# total # of packets: 99980
# # of UDP packets: 99980
# # of TCP packets: 0
# # of other packets except for TCP or UDP: 0
# Features: ips,protocol,total_length,src_port,dst_port,udp_length
# AMI scores:  [0.15951181234004858, 3.3081807150146605e-15, 0.4711922319311894, 0.17492912075294678, 0.4343788394978032, 0.47121579343209896]
# Most important feature:  5
# 234.5773401260376
# 45 / 159
# #####################################
# attackkey:  e80b7c70e4932c8e5e5d98a3269e06fe
# total # of packets: 92
# # of UDP packets: 48
# # of TCP packets: 0
# # of other packets except for TCP or UDP: 44
# Features: ips,protocol,total_length,src_port,dst_port,udp_length
# AMI scores:  [0.002755792335278955, 0.5761102817528171, 0.002547966079969974, 0.0035315206755853115, 0.0033687950029137694, 0.0030266059815784972]
# Most important feature:  1
# 236.02202439308167
# 46 / 159
# #####################################
# attackkey:  324fe87b957724e969ef1e3893ea67b6
# total # of packets: 7612
# # of UDP packets: 7612
# # of TCP packets: 0
# # of other packets except for TCP or UDP: 0
# Features: ips,protocol,total_length,src_port,dst_port,udp_length
# AMI scores:  [0.09635995076117039, -2.6378691576640308e-15, 0.13854239580306174, 0.12509474945338078, 0.12079363851008294, 0.1385536946358393]
# Most important feature:  5
# 238.2920081615448
# 47 / 159
# #####################################
# attackkey:  13c4541923cb7f9f87a328ecea0e4b65
# total # of packets: 338
# # of UDP packets: 328
# # of TCP packets: 0
# # of other packets except for TCP or UDP: 10
# Features: ips,protocol,total_length,src_port,dst_port,udp_length
# AMI scores:  [0.008581034552916226, 0.0487862768279332, 0.010014350410817632, 0.010972693088982093, 0.010495527817444242, 0.010049441939805621]
# Most important feature:  1
# 239.6765775680542
# 48 / 159
# #####################################
# attackkey:  c9920708d88e92d87dc53a4f2ee9908a
# total # of packets: 113
# # of UDP packets: 64
# # of TCP packets: 0
# # of other packets except for TCP or UDP: 49
# Features: ips,protocol,total_length,src_port,dst_port,udp_length
# AMI scores:  [0.0033069891111650327, 0.5337498568189802, 0.0029250419937190235, 0.004234804134348483, 0.004044081474421488, 0.0038095832339781447]
# Most important feature:  1
# 241.06375908851624
# 49 / 159
# #####################################
# attackkey:  ebfe0afeea7f5417f340782d8a4d6f83
# total # of packets: 6292
# # of UDP packets: 6292
# # of TCP packets: 0
# # of other packets except for TCP or UDP: 0
# Features: ips,protocol,total_length,src_port,dst_port,udp_length
# AMI scores:  [0.08319925462533656, 2.04963944025092e-14, 0.11817900348553989, 0.11000909025600325, 0.09593496004606517, 0.11818864235729573]
# Most important feature:  5
# 243.12954139709473
# 50 / 159
# #####################################
# attackkey:  14c2e0338c67991010edb19bd3ad4b8b
# total # of packets: 88
# # of UDP packets: 51
# # of TCP packets: 0
# # of other packets except for TCP or UDP: 37
# Features: ips,protocol,total_length,src_port,dst_port,udp_length
# AMI scores:  [0.00264892848001523, 0.5234698962661339, 0.0025722587457153424, 0.0033951626923411676, 0.003251783098961134, 0.0029333447510141485]
# Most important feature:  1
# 244.43369436264038
# 51 / 159
# #####################################
# attackkey:  1a2e433cfed7bde38732f0892fbbff27
# total # of packets: 122
# # of UDP packets: 77
# # of TCP packets: 0
# # of other packets except for TCP or UDP: 45
# Features: ips,protocol,total_length,src_port,dst_port,udp_length
# AMI scores:  [0.003538736953957716, 0.471127038507312, 0.003478710911585099, 0.004530393247493721, 0.004312215872057431, 0.003898819984013414]
# Most important feature:  1
# 245.73845624923706
# 52 / 159
# #####################################
# attackkey:  a60c98fd7a78dfdcded33d10dd889e2e
# total # of packets: 1376
# # of UDP packets: 1376
# # of TCP packets: 0
# # of other packets except for TCP or UDP: 0
# Features: ips,protocol,total_length,src_port,dst_port,udp_length
# AMI scores:  [0.02756717721112062, 6.723572754665125e-14, 0.03778982908438908, 0.03520708854111154, 0.03318116641529886, 0.037793229588283364]
# Most important feature:  5
# 247.30217742919922
# 53 / 159
# #####################################
# attackkey:  d9103c17cf563a8a40d3ec0dfff0fcb7
# total # of packets: 2
# # of UDP packets: 2
# # of TCP packets: 0
# # of other packets except for TCP or UDP: 0
# Features: ips,protocol,total_length,src_port,dst_port,udp_length
# AMI scores:  [7.612455518798831e-05, 0.0, 0.00011545251753201336, 0.00010310237659723094, 9.776512584925292e-05, 0.00011546590977849658]
# Most important feature:  5
# 248.5081627368927
# 54 / 159
# #####################################
# attackkey:  974dc23908b40cd3c28be24e053de886
# total # of packets: 280
# # of UDP packets: 280
# # of TCP packets: 0
# # of other packets except for TCP or UDP: 0
# Features: ips,protocol,total_length,src_port,dst_port,udp_length
# AMI scores:  [0.007308298653755319, -7.961231232547978e-13, 0.007244845896968431, 0.005570285673717165, 0.008935304032764204, 0.007245589840367675]
# Most important feature:  4
# 249.90180587768555
# 55 / 159
# #####################################
# attackkey:  45cb858201114ef20e94ce24ba917d8d
# total # of packets: 107
# # of UDP packets: 62
# # of TCP packets: 0
# # of other packets except for TCP or UDP: 45
# Features: ips,protocol,total_length,src_port,dst_port,udp_length
# AMI scores:  [0.003151168036510986, 0.5219976296250405, 0.0027110999702208765, 0.004035913391098665, 0.00385690482164785, 0.0035072365207143067]
# Most important feature:  1
# 251.25247240066528
# 56 / 159
# #####################################
# attackkey:  58c00bfa1a7cdeed42dec16b50b7a299
# total # of packets: 1040
# # of UDP packets: 1040
# # of TCP packets: 0
# # of other packets except for TCP or UDP: 0
# Features: ips,protocol,total_length,src_port,dst_port,udp_length
# AMI scores:  [0.02200975093465138, -1.8704450532694573e-15, 0.02996847957748868, 0.028085155232283523, 0.026577854442542265, 0.029971194785730543]
# Most important feature:  5
# 252.8298316001892
# 57 / 159
# #####################################
# attackkey:  20951de69e85a3917bd2606e6fea77f9_2
# total # of packets: 12
# # of UDP packets: 12
# # of TCP packets: 0
# # of other packets except for TCP or UDP: 0
# Features: ips,protocol,total_length,src_port,dst_port,udp_length
# AMI scores:  [0.0004266633931378054, 1.2980251118602282e-11, 0.00022600193400165367, 0.0005572953419630883, 0.0005303239826069553, 0.00022603727798275436]
# Most important feature:  3
# 254.44768500328064
# 58 / 159
# #####################################
# attackkey:  327c4fea908ad500186f3b281ffd9c85
# total # of packets: 917
# # of UDP packets: 917
# # of TCP packets: 0
# # of other packets except for TCP or UDP: 0
# Features: ips,protocol,total_length,src_port,dst_port,udp_length
# AMI scores:  [0.019798416556141316, 1.7314209158798334e-15, 0.024847552146684073, 0.025341055723728852, 0.0235901928371557, 0.024849812488279624]
# Most important feature:  3
# 256.17303013801575
# 59 / 159
# #####################################
# attackkey:  af7af871db3ea21fe00c37f70e6d11cb
# total # of packets: 246
# # of UDP packets: 246
# # of TCP packets: 0
# # of other packets except for TCP or UDP: 0
# Features: ips,protocol,total_length,src_port,dst_port,udp_length
# AMI scores:  [0.0065316866014130445, 2.903059517361735e-16, 0.007733190989209412, 0.008352159425380685, 0.007895081023096618, 0.00773398819248908]
# Most important feature:  3
# 257.56283712387085
# 60 / 159
# #####################################
# attackkey:  55e711623f86622365194f1ee1fb9a7e
# total # of packets: 53
# # of UDP packets: 53
# # of TCP packets: 0
# # of other packets except for TCP or UDP: 0
# Features: ips,protocol,total_length,src_port,dst_port,udp_length
# AMI scores:  [0.0016811000633179252, -2.7886455857758555e-16, 0.0017179115730296365, 0.0021606156537647006, 0.0020403622835902125, 0.0017181228340218152]
# Most important feature:  3
# 258.8772256374359
# 61 / 159
# #####################################
# attackkey:  10c774e657315ee95dc8501cdfb7f3fa
# total # of packets: 352
# # of UDP packets: 352
# # of TCP packets: 0
# # of other packets except for TCP or UDP: 0
# Features: ips,protocol,total_length,src_port,dst_port,udp_length
# AMI scores:  [0.008880820710071615, 2.1772414536743011e-13, 0.010422512420203743, 0.011361294354497778, 0.010674517061764232, 0.010423536189862286]
# Most important feature:  3
# 260.2862870693207
# 62 / 159
# #####################################
# attackkey:  d8ecc4556c6300355248ce2df77c49d3
# total # of packets: 370
# # of UDP packets: 370
# # of TCP packets: 0
# # of other packets except for TCP or UDP: 0
# Features: ips,protocol,total_length,src_port,dst_port,udp_length
# AMI scores:  [0.009282042635801513, -2.043846200980861e-16, 0.009730077591537883, 0.011855057860630062, 0.011210066851671951, 0.009731032427159647]
# Most important feature:  3
# 261.7751545906067
# 63 / 159
# #####################################
# attackkey:  53a2d63780a514261970a776520c571c
# total # of packets: 72
# # of UDP packets: 72
# # of TCP packets: 0
# # of other packets except for TCP or UDP: 0
# Features: ips,protocol,total_length,src_port,dst_port,udp_length
# AMI scores:  [0.0022144961592392154, 2.1256248966100612e-16, 0.00157511934966651, 0.002841182249056718, 0.0026560426936016804, 0.0015753278192365658]
# Most important feature:  3
# 263.19734811782837
# 64 / 159
# #####################################
# attackkey:  9c436570b69e98e36fcff55f51b7db02
# total # of packets: 290
# # of UDP packets: 290
# # of TCP packets: 0
# # of other packets except for TCP or UDP: 0
# Features: ips,protocol,total_length,src_port,dst_port,udp_length
# AMI scores:  [0.00751739197001488, 7.708825182558016e-13, 0.007986781154288225, 0.009624018124414487, 0.009213777615481623, 0.007987592735028682]
# Most important feature:  3
# 264.6084032058716
# 65 / 159
# #####################################
# attackkey:  524daa91009bad8692f7770dc61beb72
# total # of packets: 306
# # of UDP packets: 306
# # of TCP packets: 0
# # of other packets except for TCP or UDP: 0
# Features: ips,protocol,total_length,src_port,dst_port,udp_length
# AMI scores:  [0.00787792165300294, 7.374486425232559e-13, 0.008939729515973441, 0.010078107642296195, 0.009520507185333215, 0.008940626100269909]
# Most important feature:  3
# 265.97501373291016
# 66 / 159
# #####################################
# attackkey:  26d9ccb748258b7ffced4190fdaf32ad
# total # of packets: 722
# # of UDP packets: 722
# # of TCP packets: 0
# # of other packets except for TCP or UDP: 0
# Features: ips,protocol,total_length,src_port,dst_port,udp_length
# AMI scores:  [0.01621044831678678, 3.528476823222362e-13, 0.018353860370473596, 0.020806493184918805, 0.019712759542669496, 0.018355544053655855]
# Most important feature:  3
# 267.4634356498718
# 67 / 159
# #####################################
# attackkey:  674cdc64e1c911f123891e4a4c61bc1f
# total # of packets: 10
# # of UDP packets: 10
# # of TCP packets: 0
# # of other packets except for TCP or UDP: 0
# Features: ips,protocol,total_length,src_port,dst_port,udp_length
# AMI scores:  [0.00035915233248510906, 0.0, 0.00018598796053637964, 0.0004705069742246982, 0.0004474572361599182, 0.00018601732301240357]
# Most important feature:  3
# 268.7009747028351
# 68 / 159
# #####################################
# attackkey:  60799e823b0704562c763b07c4df5a55
# total # of packets: 9
# # of UDP packets: 9
# # of TCP packets: 0
# # of other packets except for TCP or UDP: 0
# Features: ips,protocol,total_length,src_port,dst_port,udp_length
# AMI scores:  [0.0003250056942272331, 1.684217092053513e-11, 0.00016611570629055202, 0.00042654322552627386, 0.0004055082006827987, 0.0001661420715163258]
# Most important feature:  3
# 269.9354465007782
# 69 / 159
# #####################################
# attackkey:  eea4d8aa213a1b0c499e50b2d956d618
# total # of packets: 360
# # of UDP packets: 360
# # of TCP packets: 0
# # of other packets except for TCP or UDP: 0
# Features: ips,protocol,total_length,src_port,dst_port,udp_length
# AMI scores:  [0.00905677216992031, 4.184661455238946e-16, 0.010561090735864802, 0.011581296864474821, 0.010951660891748165, 0.010562125585864848]
# Most important feature:  3
# 271.3382773399353
# 70 / 159
# #####################################
# attackkey:  dbd0756e16cc985a81741fbe048627c7
# total # of packets: 877675
# # of UDP packets: 834595
# # of TCP packets: 0
# # of other packets except for TCP or UDP: 43080
# Features: ips,protocol,total_length,src_port,dst_port,udp_length
# AMI scores:  [0.11665445104326899, 0.023140475090706908, 0.6074188675109616, 0.5799211705106627, 0.07591682729936972, 0.5950689518183092]
# Most important feature:  2
# 319.7224950790405
# 71 / 159
# #####################################
# attackkey:  565f16c101f6e26f25cbdc0f0258e04b
# total # of packets: 311
# # of UDP packets: 311
# # of TCP packets: 0
# # of other packets except for TCP or UDP: 0
# Features: ips,protocol,total_length,src_port,dst_port,udp_length
# AMI scores:  [0.007989386909482499, 7.274106302616801e-13, 0.009233670712182946, 0.010219155081111818, 0.009636279005334585, 0.009234593678097517]
# Most important feature:  3
# 321.19539856910706
# 72 / 159
# #####################################
# attackkey:  5bdf5fc1273bda23ccaff90e5cffb40f
# total # of packets: 204
# # of UDP packets: 204
# # of TCP packets: 0
# # of other packets except for TCP or UDP: 0
# Features: ips,protocol,total_length,src_port,dst_port,udp_length
# AMI scores:  [0.005550629742280533, 1.0473341165442937e-12, 0.006265296228650655, 0.007102287754663141, 0.006735456266263002, 0.0062659623143266245]
# Most important feature:  3
# 322.70003962516785
# 73 / 159
# #####################################
# attackkey:  68387e4ccd91c2f0a78bd8050165b33a
# total # of packets: 106
# # of UDP packets: 106
# # of TCP packets: 0
# # of other packets except for TCP or UDP: 0
# Features: ips,protocol,total_length,src_port,dst_port,udp_length
# AMI scores:  [0.0031262318950289864, 3.023270100609267e-16, 0.0035460912858169148, 0.004003494117569772, 0.003801094634059248, 0.003546497874512349]
# Most important feature:  3
# 324.0506055355072
# 74 / 159
# #####################################
# attackkey:  5e08c144bd92404c22e7c8bf5aa1f75a
# total # of packets: 9
# # of UDP packets: 9
# # of TCP packets: 0
# # of other packets except for TCP or UDP: 0
# Features: ips,protocol,total_length,src_port,dst_port,udp_length
# AMI scores:  [0.0003250056942272331, 1.684217092053513e-11, 0.00016611570629055202, 0.00042654322552627386, 0.0004055082006827987, 0.0001661420715163258]
# Most important feature:  3
# 325.34617829322815
# 75 / 159
# #####################################
# attackkey:  5d3064fec54e8e50c1eee178329cbed3
# total # of packets: 145
# # of UDP packets: 85
# # of TCP packets: 0
# # of other packets except for TCP or UDP: 60
# Features: ips,protocol,total_length,src_port,dst_port,udp_length
# AMI scores:  [0.0041196156114245595, 0.5130413910215939, 0.003953036298356726, 0.005271846486441474, 0.005044915895330608, 0.004678739797590902]
# Most important feature:  1
# 326.70348262786865
# 76 / 159
# #####################################
# attackkey:  bf1727bdaefe5ddd4cef7fdfecdf2379
# total # of packets: 1000
# # of UDP packets: 1000
# # of TCP packets: 0
# # of other packets except for TCP or UDP: 0
# Features: ips,protocol,total_length,src_port,dst_port,udp_length
# AMI scores:  [0.021145702086324904, -1.885353896631226e-15, 0.024845479671481093, 0.027201717851513412, 0.025668268461844983, 0.024847731652577528]
# Most important feature:  3
# 328.28251099586487
# 77 / 159
# #####################################
# attackkey:  d0a8baa3a49351a64abe15bacfcbfd4c
# total # of packets: 94
# # of UDP packets: 94
# # of TCP packets: 0
# # of other packets except for TCP or UDP: 0
# Features: ips,protocol,total_length,src_port,dst_port,udp_length
# AMI scores:  [0.0028085802950286844, -3.3601718803933094e-16, 0.0029753753485372266, 0.003600115364685638, 0.003405257391033414, 0.0029757246480007758]
# Most important feature:  3
# 329.60087513923645
# 78 / 159
# #####################################
# attackkey:  97fd9c08bd2d121abbe4d9d7e85a9fab
# total # of packets: 138
# # of UDP packets: 86
# # of TCP packets: 0
# # of other packets except for TCP or UDP: 52
# Features: ips,protocol,total_length,src_port,dst_port,udp_length
# AMI scores:  [0.003944483899509125, 0.477937391787794, 0.003803048676901492, 0.00504818158671274, 0.004824797960263999, 0.00440175739068917]
# Most important feature:  1
# 330.9217858314514
# 79 / 159
# #####################################
# attackkey:  6c94d9829f082c1d8174d6086d840667
# total # of packets: 434
# # of UDP packets: 434
# # of TCP packets: 0
# # of other packets except for TCP or UDP: 0
# Features: ips,protocol,total_length,src_port,dst_port,udp_length
# AMI scores:  [0.01061372746773048, -3.5672740609456147e-16, 0.013459382705632785, 0.013576568054312751, 0.012777099135982564, 0.013460668777050306]
# Most important feature:  3
# 332.4128305912018
# 80 / 159
# #####################################
# attackkey:  473d2481db15f5d783405db702ed72e7
# total # of packets: 1319
# # of UDP packets: 1319
# # of TCP packets: 0
# # of other packets except for TCP or UDP: 0
# Features: ips,protocol,total_length,src_port,dst_port,udp_length
# AMI scores:  [0.026529907672501886, 5.631741538164573e-16, 0.036502081003602145, 0.03403346341878329, 0.03183276176857378, 0.036505369167780556]
# Most important feature:  5
# 333.9651184082031
# 81 / 159
# #####################################
# attackkey:  7a692d24819c8ec6ddc4e17b6eeff455
# total # of packets: 131
# # of UDP packets: 71
# # of TCP packets: 0
# # of other packets except for TCP or UDP: 60
# Features: ips,protocol,total_length,src_port,dst_port,udp_length
# AMI scores:  [0.0037677556336400382, 0.5548643023634602, 0.003504151018589641, 0.00482274252771655, 0.004622440812288675, 0.004252042468347088]
# Most important feature:  1
# 335.27553391456604
# 82 / 159
# #####################################
# attackkey:  c10abd75258803ae46144e1f206b93f5
# total # of packets: 107
# # of UDP packets: 55
# # of TCP packets: 0
# # of other packets except for TCP or UDP: 52
# Features: ips,protocol,total_length,src_port,dst_port,udp_length
# AMI scores:  [0.0031510378292702815, 0.5817266368293308, 0.002988562370800649, 0.0040358974331025175, 0.003867293171033932, 0.003543183004364329]
# Most important feature:  1
# 336.5790021419525
# 83 / 159
# #####################################
# attackkey:  cd308b6eabf0d0d84028e8f6d812ec27
# total # of packets: 178
# # of UDP packets: 106
# # of TCP packets: 0
# # of other packets except for TCP or UDP: 72
# Features: ips,protocol,total_length,src_port,dst_port,udp_length
# AMI scores:  [0.004929477136198887, 0.50239743115549, 0.004753329309254632, 0.0063058645297027136, 0.006018015829884183, 0.005362100184709756]
# Most important feature:  1
# 337.88916516304016
# 84 / 159
# #####################################
# attackkey:  3301b2c6bccac62779ec816a372e8641
# total # of packets: 168
# # of UDP packets: 103
# # of TCP packets: 0
# # of other packets except for TCP or UDP: 65
# Features: ips,protocol,total_length,src_port,dst_port,udp_length
# AMI scores:  [0.004686779914527384, 0.4860583622686076, 0.004384396563441836, 0.005995918417582654, 0.005748488981513014, 0.005315230244033982]
# Most important feature:  1
# 339.1937186717987
# 85 / 159
# #####################################
# attackkey:  a8fa7478dc84619cc3ff106a04363c00
# total # of packets: 826799
# # of UDP packets: 776803
# # of TCP packets: 0
# # of other packets except for TCP or UDP: 49996
# Features: ips,protocol,total_length,src_port,dst_port,udp_length
# AMI scores:  [0.12023966279418795, 0.028063253108093548, 0.0832119447394629, 0.5803477209344048, 0.07928097435437421, 0.08439404798155115]
# Most important feature:  3
# 385.78946232795715
# 86 / 159
# #####################################
# attackkey:  b13265de1c866fb86021595e564a2ff2
# total # of packets: 960
# # of UDP packets: 960
# # of TCP packets: 0
# # of other packets except for TCP or UDP: 0
# Features: ips,protocol,total_length,src_port,dst_port,udp_length
# AMI scores:  [0.020628941174211424, 2.773205066616499e-13, 0.02750432562228884, 0.026309770104967007, 0.025010801442961427, 0.027506819411276383]
# Most important feature:  5
# 387.28865337371826
# 87 / 159
# #####################################
# attackkey:  7c48b9dc3286acde9c1419cd07be1c7d
# total # of packets: 162
# # of UDP packets: 162
# # of TCP packets: 0
# # of other packets except for TCP or UDP: 0
# Features: ips,protocol,total_length,src_port,dst_port,udp_length
# AMI scores:  [0.004541166012505531, -6.257406992114224e-16, 0.00540009556899228, 0.005810437983515375, 0.00551729208550028, 0.005400683004760101]
# Most important feature:  3
# 388.5951042175293
# 88 / 159
# #####################################
# attackkey:  d7402eceef0df214a61e9e31a20097c9
# total # of packets: 372
# # of UDP packets: 372
# # of TCP packets: 0
# # of other packets except for TCP or UDP: 0
# Features: ips,protocol,total_length,src_port,dst_port,udp_length
# AMI scores:  [0.00930667910740355, 2.0344438234491836e-16, 0.011349714031666092, 0.011909647275552155, 0.011243672808534035, 0.011350819002886576]
# Most important feature:  3
# 389.9758868217468
# 89 / 159
# #####################################
# attackkey:  948922a24621857f60ff55f0b92d225f
# total # of packets: 98
# # of UDP packets: 52
# # of TCP packets: 0
# # of other packets except for TCP or UDP: 46
# Features: ips,protocol,total_length,src_port,dst_port,udp_length
# AMI scores:  [0.002914908082794571, 0.5676292303189682, 0.0029109216943108886, 0.0037345555962988576, 0.0035636216175829565, 0.0032577444664788242]
# Most important feature:  1
# 391.27727484703064
# 90 / 159
# #####################################
# attackkey:  187e8c4e14e803d71c75b2cd102b6fc2
# total # of packets: 1404
# # of UDP packets: 1404
# # of TCP packets: 0
# # of other packets except for TCP or UDP: 0
# Features: ips,protocol,total_length,src_port,dst_port,udp_length
# AMI scores:  [0.027859874232852775, 6.789731082341956e-14, 0.03837643177038228, 0.03577888047394688, 0.03338410614586096, 0.03837988321702712]
# Most important feature:  5
# 393.03588485717773
# 91 / 159
# #####################################
# attackkey:  72666503ae7af37518dbba7c85c80418
# total # of packets: 1143
# # of UDP packets: 1143
# # of TCP packets: 0
# # of other packets except for TCP or UDP: 0
# Features: ips,protocol,total_length,src_port,dst_port,udp_length
# AMI scores:  [0.0237462283877188, 2.4144709554982115e-13, 0.03242600574495582, 0.030322925300331583, 0.028631631266849582, 0.032428936827655054]
# Most important feature:  5
# 394.5491931438446
# 92 / 159
# #####################################
# attackkey:  e9500bc4af5548ba856451a23466073e
# total # of packets: 7394
# # of UDP packets: 7394
# # of TCP packets: 0
# # of other packets except for TCP or UDP: 0
# Features: ips,protocol,total_length,src_port,dst_port,udp_length
# AMI scores:  [0.09431715174447744, 1.72083942546809e-14, 0.13611753028135626, 0.12272166113834812, 0.11846092142659595, 0.1361286676277124]
# Most important feature:  5
# 396.5678696632385
# 93 / 159
# #####################################
# attackkey:  02a3a3fc266b09b7645e538efbc1ea11
# total # of packets: 560
# # of UDP packets: 560
# # of TCP packets: 0
# # of other packets except for TCP or UDP: 0
# Features: ips,protocol,total_length,src_port,dst_port,udp_length
# AMI scores:  [0.013185839903113852, 4.4031994146075125e-13, 0.01762331680768121, 0.01683197121784764, 0.015960521546514957, 0.017624959300773946]
# Most important feature:  5
# 398.06165289878845
# 94 / 159
# #####################################
# attackkey:  9a0c14fc67a9e8a7c03dd118dc088395
# total # of packets: 363
# # of UDP packets: 363
# # of TCP packets: 0
# # of other packets except for TCP or UDP: 0
# Features: ips,protocol,total_length,src_port,dst_port,udp_length
# AMI scores:  [0.00913592152651015, 6.383184839258351e-13, 0.01185349844268927, 0.011663568698561185, 0.011072176600317098, 0.0118546521583223]
# Most important feature:  5
# 399.45983123779297
# 95 / 159
# #####################################
# attackkey:  5cc22060a7e9457ee619db0c95efeadd
# total # of packets: 91
# # of UDP packets: 91
# # of TCP packets: 0
# # of other packets except for TCP or UDP: 0
# Features: ips,protocol,total_length,src_port,dst_port,udp_length
# AMI scores:  [0.002729599310964967, -2.124258057319746e-12, 0.002900085487845701, 0.00349818273471534, 0.003317741703707338, 0.0029004267592727287]
# Most important feature:  3
# 400.83783650398254
# 96 / 159
# #####################################
# attackkey:  108313535654e36e9780bbcc71e14248
# total # of packets: 358
# # of UDP packets: 358
# # of TCP packets: 0
# # of other packets except for TCP or UDP: 0
# Features: ips,protocol,total_length,src_port,dst_port,udp_length
# AMI scores:  [0.00902810688218147, -2.1538404068317224e-13, 0.010712206370663058, 0.01152637991245336, 0.011001708746734227, 0.010713254608866291]
# Most important feature:  3
# 402.28542947769165
# 97 / 159
# #####################################
# attackkey:  a877a80fc3e21a6f001c4d2f514ed993
# total # of packets: 128132
# # of UDP packets: 128132
# # of TCP packets: 0
# # of other packets except for TCP or UDP: 0
# Features: ips,protocol,total_length,src_port,dst_port,udp_length
# AMI scores:  [0.144831168345584, -7.11855669049695e-15, 0.5030432252965233, 0.16477536546708887, 0.4672188299724921, 0.5023469759950909]
# Most important feature:  2
# 411.72688364982605
# 98 / 159
# #####################################
# attackkey:  380b2fa846c7b041de49fd565bc4b231
# total # of packets: 112
# # of UDP packets: 64
# # of TCP packets: 0
# # of other packets except for TCP or UDP: 48
# Features: ips,protocol,total_length,src_port,dst_port,udp_length
# AMI scores:  [0.0032811136239438493, 0.5291189328417801, 0.0029301320882643925, 0.004201763380857944, 0.004026242067652993, 0.00357462732432115]
# Most important feature:  1
# 413.09205412864685
# 99 / 159
# #####################################
# attackkey:  79c0560b679610429eb83424c59852fc
# total # of packets: 8
# # of UDP packets: 8
# # of TCP packets: 0
# # of other packets except for TCP or UDP: 0
# Features: ips,protocol,total_length,src_port,dst_port,udp_length
# AMI scores:  [0.0002905725619100433, -6.2483243833916365e-12, 0.00014634969818396772, 0.00038215389426998335, 0.00036317456816925943, 0.0001463730632482749]
# Most important feature:  3
# 414.37019324302673
# 100 / 159
# #####################################
# attackkey:  0c2b1312ce22a317922ee510b1a7c7a5
# total # of packets: 720318
# # of UDP packets: 675211
# # of TCP packets: 0
# # of other packets except for TCP or UDP: 45107
# Features: ips,protocol,total_length,src_port,dst_port,udp_length
# AMI scores:  [0.12764028648475934, 0.030672046854407938, 0.5943234609000192, 0.564933302865142, 0.08569781233219205, 0.5944605458299104]
# Most important feature:  5
# 452.96288871765137
# 101 / 159
# #####################################
# attackkey:  03c18359ae35b93a3657b5971fd952fa
# total # of packets: 295
# # of UDP packets: 295
# # of TCP packets: 0
# # of other packets except for TCP or UDP: 0
# Features: ips,protocol,total_length,src_port,dst_port,udp_length
# AMI scores:  [0.007637804595017677, 2.5393386792286606e-13, 0.009848924300284017, 0.009766376775888992, 0.009314646021536001, 0.009849908151508971]
# Most important feature:  5
# 454.33098220825195
# 102 / 159
# #####################################
# attackkey:  2130bfd08fae290ef08e562aefdb21b9
# total # of packets: 184
# # of UDP packets: 114
# # of TCP packets: 0
# # of other packets except for TCP or UDP: 70
# Features: ips,protocol,total_length,src_port,dst_port,udp_length
# AMI scores:  [0.0050742793776342165, 0.47897303927784685, 0.005204602978378166, 0.006490574990518227, 0.00620828368116052, 0.005761261951523627]
# Most important feature:  1
# 455.6586720943451
# 103 / 159
# #####################################
# attackkey:  06fd611bee580290adb83b5a2bc0f069
# total # of packets: 92
# # of UDP packets: 56
# # of TCP packets: 0
# # of other packets except for TCP or UDP: 36
# Features: ips,protocol,total_length,src_port,dst_port,udp_length
# AMI scores:  [0.0027558444066879827, 0.49530551832376746, 0.002522925255829098, 0.003531543240873837, 0.0033827604295191276, 0.0029620900919186195]
# Most important feature:  1
# 456.9996201992035
# 104 / 159
# #####################################
# attackkey:  a11ba565a01155351afe6d433594d238
# total # of packets: 3790
# # of UDP packets: 3790
# # of TCP packets: 0
# # of other packets except for TCP or UDP: 0
# Features: ips,protocol,total_length,src_port,dst_port,udp_length
# ...
# # of other packets except for TCP or UDP: 0
# Features: ips,protocol,total_length,src_port,dst_port,udp_length
# AMI scores:  [0.00877218373620328, 1.8661360060959794e-15, 0.01093982057891796, 0.011223335101504089, 0.010525139851716363, 0.010940893640343284]
# Most important feature:  3
# 522.1510059833527
# 123 / 159
# #####################################
# attackkey:  a8f13befb53acd25aec1c3f92b1ee02b
# total # of packets: 1792
# # of UDP packets: 1792
# # of TCP packets: 0
# # of other packets except for TCP or UDP: 0
# Features: ips,protocol,total_length,src_port,dst_port,udp_length
# AMI scores:  [0.033766937575647214, -1.9620426068238044e-15, 0.04676339031417063, 0.04341211743250499, 0.040341264529199825, 0.04676756448025383]
# Most important feature:  5
# 523.7404549121857
# 124 / 159
# #####################################
# attackkey:  abdc10fabdb343768c96dc3e3d30372a
# total # of packets: 698
# # of UDP packets: 698
# # of TCP packets: 0
# # of other packets except for TCP or UDP: 0
# Features: ips,protocol,total_length,src_port,dst_port,udp_length
# AMI scores:  [0.015810873978738923, 3.6448323623732013e-13, 0.019393839691743547, 0.020230688331114542, 0.018874985596093866, 0.019395623447916836]
# Most important feature:  3
# 525.2056701183319
# 125 / 159
# #####################################
# attackkey:  a3644f57a18ccb958a3d64f96e943828
# total # of packets: 306
# # of UDP packets: 306
# # of TCP packets: 0
# # of other packets except for TCP or UDP: 0
# Features: ips,protocol,total_length,src_port,dst_port,udp_length
# AMI scores:  [0.007879747646078187, 7.374486425232559e-13, 0.009241547050010183, 0.010078107642296195, 0.009525294880859386, 0.009242471946216345]
# Most important feature:  3
# 526.653139591217
# 126 / 159
# #####################################
# attackkey:  6297de9c19ce35bb4738bd3687512a9a
# total # of packets: 102
# # of UDP packets: 102
# # of TCP packets: 0
# # of other packets except for TCP or UDP: 0
# Features: ips,protocol,total_length,src_port,dst_port,udp_length
# AMI scores:  [0.0030204653368750252, 1.9203873630859377e-12, 0.0034740696188898966, 0.0038697804777831813, 0.003672212946621696, 0.0034744683550611386]
# Most important feature:  3
# 527.9913449287415
# 127 / 159
# #####################################
# attackkey:  e4ed2d7237e72181e0185f1d46e022de
# total # of packets: 291
# # of UDP packets: 291
# # of TCP packets: 0
# # of other packets except for TCP or UDP: 0
# Features: ips,protocol,total_length,src_port,dst_port,udp_length
# AMI scores:  [0.007550170844360365, 0.0, 0.009106422618021186, 0.00965252352625253, 0.009108950080537538, 0.009107338593140137]
# Most important feature:  3
# 529.4660859107971
# 128 / 159
# #####################################
# attackkey:  e85739e64cf0f7882f36f676c5114fac
# total # of packets: 134
# # of UDP packets: 79
# # of TCP packets: 0
# # of other packets except for TCP or UDP: 55
# Features: ips,protocol,total_length,src_port,dst_port,udp_length
# AMI scores:  [0.003843639941490207, 0.5105637048607067, 0.0036863860998863855, 0.004919572059276698, 0.004701272133304437, 0.0043279273543891765]
# Most important feature:  1
# 530.7803449630737
# 129 / 159
# #####################################
# attackkey:  2bf238448118adaa7dc3695830b084af
# total # of packets: 325
# # of UDP packets: 325
# # of TCP packets: 0
# # of other packets except for TCP or UDP: 0
# Features: ips,protocol,total_length,src_port,dst_port,udp_length
# AMI scores:  [0.008292968096656498, 0.0, 0.010389530882825074, 0.010611996596292514, 0.01001420796777553, 0.010390558273794896]
# Most important feature:  3
# 532.4055528640747
# 130 / 159
# #####################################
# attackkey:  8e4c9e0a6e37b2eb954a868db67b6b4d
# total # of packets: 242
# # of UDP packets: 242
# # of TCP packets: 0
# # of other packets except for TCP or UDP: 0
# Features: ips,protocol,total_length,src_port,dst_port,udp_length
# AMI scores:  [0.006439205362137687, 3.0103595451666013e-13, 0.007595500413634836, 0.008234725361429641, 0.00776806964773773, 0.007596285398680098]
# Most important feature:  3
# 533.9237613677979
# 131 / 159
# #####################################
# attackkey:  bd9cb3b69f02c8fdba7efc5bb8a6a4db
# total # of packets: 379
# # of UDP packets: 379
# # of TCP packets: 0
# # of other packets except for TCP or UDP: 0
# Features: ips,protocol,total_length,src_port,dst_port,udp_length
# AMI scores:  [0.009447812454696936, 2.0433178509094067e-13, 0.009900742734416148, 0.01210028973942634, 0.011546598602658364, 0.009901711196270263]
# Most important feature:  3
# 535.3439018726349
# 132 / 159
# #####################################
# attackkey:  bf0d6dd9cc4e2914a0403eadc58e4973
# total # of packets: 323
# # of UDP packets: 323
# # of TCP packets: 0
# # of other packets except for TCP or UDP: 0
# Features: ips,protocol,total_length,src_port,dst_port,udp_length
# AMI scores:  [0.008251691244451558, 4.592340748118894e-16, 0.010178670959022657, 0.010556061906933601, 0.009880489193756043, 0.010179679011273169]
# Most important feature:  3
# 536.7175288200378
# 133 / 159
# #####################################
# attackkey:  48c48a867ca52d948973303bc721b39f
# total # of packets: 1428944
# # of UDP packets: 1369078
# # of TCP packets: 0
# # of other packets except for TCP or UDP: 59866
# Features: ips,protocol,total_length,src_port,dst_port,udp_length
# AMI scores:  [0.08830448582493425, 0.016393255036447552, 0.10933606516907612, 0.5881543719813611, 0.592952059339553, 0.11189871073917772]
# Most important feature:  4
# 608.7587792873383
# 134 / 159
# #####################################
# attackkey:  44d4d7003771cd49b724bbbff150fb06
# total # of packets: 107
# # of UDP packets: 73
# # of TCP packets: 0
# # of other packets except for TCP or UDP: 34
# Features: ips,protocol,total_length,src_port,dst_port,udp_length
# AMI scores:  [0.0031513102553276276, 0.42025424657860344, 0.0029534600684530165, 0.0040359853349759165, 0.0038473253813087927, 0.003409963824916714]
# Most important feature:  1
# 610.2971742153168
# 135 / 159
# #####################################
# attackkey:  6a2cde8c04be281ee0ddff2e1a3bd21e
# total # of packets: 9
# # of UDP packets: 9
# # of TCP packets: 0
# # of other packets except for TCP or UDP: 0
# Features: ips,protocol,total_length,src_port,dst_port,udp_length
# AMI scores:  [0.0003250056942272331, 1.684217092053513e-11, 0.00016611570629055202, 0.0004200055935183819, 0.0004055082006827987, 0.0001661420715163258]
# Most important feature:  3
# 611.829009771347
# 136 / 159
# #####################################
# attackkey:  c3ea1742df4569fa778eaab379bd8772
# total # of packets: 360
# # of UDP packets: 360
# # of TCP packets: 0
# # of other packets except for TCP or UDP: 0
# Features: ips,protocol,total_length,src_port,dst_port,udp_length
# AMI scores:  [0.009071126679326306, 4.184661455238946e-16, 0.010764447450154561, 0.011581296864474821, 0.011090676027940657, 0.010765500035489324]
# Most important feature:  3
# 613.4433751106262
# 137 / 159
# #####################################
# attackkey:  05d8f0758a35f567a069a25b54cc2a22
# total # of packets: 1125000
# # of UDP packets: 1086863
# # of TCP packets: 0
# # of other packets except for TCP or UDP: 38137
# Features: ips,protocol,total_length,src_port,dst_port,udp_length
# AMI scores:  [0.10647277096387078, 0.015439182061853114, 0.06791884993218447, 0.6107453905489697, 0.6062594361941995, 0.06847445359658373]
# Most important feature:  3
# 673.9610106945038
# 138 / 159
# #####################################
# attackkey:  7ff63ada8c94b8d6064aa26f7e9efbac
# total # of packets: 185
# # of UDP packets: 185
# # of TCP packets: 0
# # of other packets except for TCP or UDP: 0
# Features: ips,protocol,total_length,src_port,dst_port,udp_length
# AMI scores:  [0.005097510740782585, 0.0, 0.006186015380238095, 0.006523599180233942, 0.006191696223831867, 0.00618667576821315]
# Most important feature:  3
# 675.4362778663635
# 139 / 159
# #####################################
# attackkey:  5745d17a8591ba66f264c19a9aa00320
# total # of packets: 267
# # of UDP packets: 267
# # of TCP packets: 0
# # of other packets except for TCP or UDP: 0
# Features: ips,protocol,total_length,src_port,dst_port,udp_length
# AMI scores:  [0.007011625299330738, -2.7048853268848347e-16, 0.00623342420730071, 0.008963601065007118, 0.00840939243264122, 0.0062340771430168095]
# Most important feature:  3
# 676.8971066474915
# 140 / 159
# #####################################
# attackkey:  74c05a70914089e0dc3c39f4c4648aac
# total # of packets: 548
# # of UDP packets: 548
# # of TCP packets: 0
# # of other packets except for TCP or UDP: 0
# Features: ips,protocol,total_length,src_port,dst_port,udp_length
# AMI scores:  [0.01291675054212633, -5.853099490979172e-16, 0.015864867719898597, 0.01652872325798901, 0.015537784762565343, 0.01586635063163552]
# Most important feature:  3
# 678.3298661708832
# 141 / 159
# #####################################
# attackkey:  cc8a3617866a4ad112ac2e7315a92e3d
# total # of packets: 123
# # of UDP packets: 123
# # of TCP packets: 0
# # of other packets except for TCP or UDP: 0
# Features: ips,protocol,total_length,src_port,dst_port,udp_length
# AMI scores:  [0.00356502754118706, -2.653396695061785e-16, 0.003919458538700234, 0.004564154881552469, 0.004333214941995761, 0.003919903821707667]
# Most important feature:  3
# 679.6290867328644
# 142 / 159
# #####################################
# attackkey:  79c0560b679610429eb83424c59852fc_2
# total # of packets: 8
# # of UDP packets: 8
# # of TCP packets: 0
# # of other packets except for TCP or UDP: 0
# Features: ips,protocol,total_length,src_port,dst_port,udp_length
# AMI scores:  [0.0002905725619100433, -6.2483243833916365e-12, 0.00014634969818396772, 0.0003756157311691189, 0.00036317456816925943, 0.0001463730632482749]
# Most important feature:  3
# 680.8645567893982
# 143 / 159
# #####################################
# attackkey:  6b443b1d79fc5ad00f9eaa65e08b5ae8
# total # of packets: 417
# # of UDP packets: 417
# # of TCP packets: 0
# # of other packets except for TCP or UDP: 0
# Features: ips,protocol,total_length,src_port,dst_port,udp_length
# AMI scores:  [0.010262345328994399, 1.8883244322829976e-13, 0.01196992982904148, 0.01312421850132276, 0.01231042701047851, 0.011971081371048055]
# Most important feature:  3
# 682.231377363205
# 144 / 159
# #####################################
# attackkey:  c8b2ee81d5d417e9bb9e23d520c477ee
# total # of packets: 634
# # of UDP packets: 634
# # of TCP packets: 0
# # of other packets except for TCP or UDP: 0
# Features: ips,protocol,total_length,src_port,dst_port,udp_length
# AMI scores:  [0.014634253755934294, 1.335241883680795e-13, 0.01921880614528435, 0.01863975417615, 0.017805231354103963, 0.019220580705656704]
# Most important feature:  5
# 683.6802277565002
# 145 / 159
# #####################################
# attackkey:  f621936359aca6116a3bd69b370c2a67
# total # of packets: 872
# # of UDP packets: 872
# # of TCP packets: 0
# # of other packets except for TCP or UDP: 0
# Features: ips,protocol,total_length,src_port,dst_port,udp_length
# AMI scores:  [0.018990067069445265, 3.026651105553221e-13, 0.02369229803392268, 0.024315856859065024, 0.02262508126618706, 0.023694456910560272]
# Most important feature:  3
# 685.1737365722656
# 146 / 159
# #####################################
# attackkey:  e9beae87c340afe2668dce0a7001ac24
# total # of packets: 293
# # of UDP packets: 167
# # of TCP packets: 0
# # of other packets except for TCP or UDP: 126
# Features: ips,protocol,total_length,src_port,dst_port,udp_length
# AMI scores:  [0.007589631759545791, 0.5214369487055687, 0.007018196445943794, 0.009704262760455867, 0.009273973244441127, 0.00866498646657641]
# Most important feature:  1
# 686.518304347992
# 147 / 159
# #####################################
# attackkey:  a7b3506d4d20bf5eff18958737bc025a
# total # of packets: 1081
# # of UDP packets: 1081
# # of TCP packets: 0
# # of other packets except for TCP or UDP: 0
# Features: ips,protocol,total_length,src_port,dst_port,udp_length
# AMI scores:  [0.022582615765166892, 2.513951560356738e-13, 0.030954085062524467, 0.028982166789139317, 0.027094811481240707, 0.030956886878873418]
# Most important feature:  5
# 688.0409872531891
# 148 / 159
# #####################################
# attackkey:  86bf22271e530d57313cc3c4d2e73c9d
# total # of packets: 421
# # of UDP packets: 421
# # of TCP packets: 0
# # of other packets except for TCP or UDP: 0
# Features: ips,protocol,total_length,src_port,dst_port,udp_length
# AMI scores:  [0.010341266315149507, 0.0, 0.012250883409817993, 0.01323096194512961, 0.012417517628227147, 0.012252059576860205]
# Most important feature:  3
# 689.4161987304688
# 149 / 159
# #####################################
# attackkey:  bf6bf159d7237d3dfcb9ff0d68764079
# total # of packets: 245
# # of UDP packets: 245
# # of TCP packets: 0
# # of other packets except for TCP or UDP: 0
# Features: ips,protocol,total_length,src_port,dst_port,udp_length
# AMI scores:  [0.006505572575153799, 1.5382044260428653e-15, 0.007469866111981179, 0.008322830790613425, 0.00788750709753103, 0.007470638600585505]
# Most important feature:  3
# 690.7718441486359
# 150 / 159
# #####################################
# something went wrong with attack  52ad3690116922df6f045fb172c5ff05
# attackkey:  1f14abf0891dd4b866da7e0621430fbd
# total # of packets: 1119028
# # of UDP packets: 1079960
# # of TCP packets: 0
# # of other packets except for TCP or UDP: 39068
# Features: ips,protocol,total_length,src_port,dst_port,udp_length
# AMI scores:  [0.10654916298011669, 0.015846445906630535, 0.06809113491351465, 0.6011083334230827, 0.604731806517386, 0.06853344217192267]
# Most important feature:  4
# 752.1938705444336
# 151 / 159
# #####################################
# attackkey:  5749449ca122e8a203a530586a1f28f2
# total # of packets: 311
# # of UDP packets: 183
# # of TCP packets: 0
# # of other packets except for TCP or UDP: 128
# Features: ips,protocol,total_length,src_port,dst_port,udp_length
# AMI scores:  [0.007988065828852446, 0.5035979930994654, 0.00840479704054704, 0.010213438439971878, 0.00976227470573446, 0.009240714338918255]
# Most important feature:  1
# 753.6404318809509
# 152 / 159
# #####################################
# attackkey:  8300a94be92bd2f0ecf489eee728b626
# total # of packets: 0
# # of UDP packets: 0
# # of TCP packets: 0
# # of other packets except for TCP or UDP: 0
# Features: ips,protocol,total_length,src_port,dst_port,udp_length
# AMI scores:  [5.953951761378233e-16, 1.0, 7.669834934216181e-16, 2.0484401348601635e-15, 8.803657203244096e-16, 7.692973660975005e-16]
# Most important feature:  1
# 754.6998763084412
# 153 / 159
# #####################################
# attackkey:  983d0d3be373f51f249d1c0144c552ed
# total # of packets: 1410972
# # of UDP packets: 1347743
# # of TCP packets: 0
# # of other packets except for TCP or UDP: 63229
# Features: ips,protocol,total_length,src_port,dst_port,udp_length
# AMI scores:  [0.08892283295972338, 0.017360370192440907, 0.1098689750838086, 0.5915381341410486, 0.5887147201563595, 0.11265383211033957]
# Most important feature:  3
# 828.1308295726776
# 154 / 159
# #####################################
# attackkey:  c093f324dc7908241b9be60bb8b58473
# total # of packets: 382
# # of UDP packets: 382
# # of TCP packets: 0
# # of other packets except for TCP or UDP: 0
# Features: ips,protocol,total_length,src_port,dst_port,udp_length
# AMI scores:  [0.009521194361481147, 1.413946977458511e-15, 0.011033763923222797, 0.012181795411578135, 0.011469638931586802, 0.011034837080357598]
# Most important feature:  3
# 829.7135100364685
# 155 / 159
# #####################################
# attackkey:  33bd295fd9249d26cd64cabb2a38b01b
# total # of packets: 130
# # of UDP packets: 130
# # of TCP packets: 0
# # of other packets except for TCP or UDP: 0
# Features: ips,protocol,total_length,src_port,dst_port,udp_length
# AMI scores:  [0.003744326632822306, 2.527850567103918e-16, 0.004271648367010553, 0.0047916987526687126, 0.004507635913205153, 0.004272127790284215]
# Most important feature:  3
# 831.1887905597687
# 156 / 159
# #####################################
# attackkey:  0da6d52ff78561c80db8f2ffca43d794
# total # of packets: 160
# # of UDP packets: 88
# # of TCP packets: 0
# # of other packets except for TCP or UDP: 72
# Features: ips,protocol,total_length,src_port,dst_port,udp_length
# AMI scores:  [0.00449083981231198, 0.5457626501961843, 0.003882004776552113, 0.0057458408764988955, 0.0055086166362800365, 0.004856333238347724]
# Most important feature:  1
# 832.5502054691315
# 157 / 159
# #####################################
# 832.5502054691315

# %% [markdown]
# ### Analysis and Conclusions

# %%
for i in range(0,6):
    print(i,most_important_features.count(i))
# Out:
# 0 0
# 1 31
# 2 3
# 3 93
# 4 4
# 5 26

# %% [markdown]
# The counts of most important feature per feature are: <br/>
#
# 0 IP address: 0 <br/>
# 1 Protocol: 31 <br/>
# 2 Total packet length: 3 <br/>
# 3 UDP source port: 93 <br/>
# 4 Destination port: 4 <br/>
# 5 UDP payload length: 26 <br/>
#
# None of the attacks has its IP address as most important feature. This can be explained by the fact that there are too much different IP addresses. Furthermore by the fact that the values of the IP addresses are laying in between each other for the normal and attack traffic.
#
# The 31 at the protocol is remarkable, since this AMI value should be zero since all packets should be UDP packets. With manual inspection we discovered that some of the attacks are mixed with ICMP packets.
#
# The UDP source port is for most attacks the distinguishing feature. UDP payload second best.
