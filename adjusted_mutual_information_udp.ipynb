# %% [markdown]
# # Feature Selection using the Adjusted Mutual Information (AMI) Score
#
# ### (UDP analysis only)
#
# This notebook uses the Adjusted Mutual Information Score to determine the most relevant features in the DDoS attacks. It uses the bigflows pcap from [http://tcpreplay.appneta.com/wiki/captures.html] containing normal network traffic. The DDoS attack pcaps from DDoSDB [https://ddosdb.org/] are used to compare it with the normal network traffic.

# %%
#all relevant libraries need to be imported
from sklearn.metrics.cluster import adjusted_mutual_info_score, mutual_info_score, normalized_mutual_info_score
from sklearn.feature_selection import mutual_info_classif
import numpy as np
import dpkt
import Utils
import ipaddress
import pandas as pd
import time
import os
import json
import operator

# %% [markdown]
# ### Load bigflows containing only UDP traffic

# %%
start = time.time()

input = open('normal_pcaps/bigflows_udp.pcap', 'rb')
normal = dpkt.pcap.Reader(input)
length = 152733 #this is the number of packets in bigflows_udp.pcap   #791615 #791179

ips_n = np.empty(length)
protocol_n = np.empty(length)
total_length_n = np.empty(length)
src_port_n = np.empty(length)
dst_port_n = np.empty(length)
udp_length_n = np.empty(length)

labels_n = np.zeros(length)

udp_packet = 0
tcp_packet = 0
other = 0
total_packet = 0
 
i=0
for ts, buf in normal:
    eth = dpkt.ethernet.Ethernet(buf)
    total_packet += 1 

    if eth.type == 2048:
        ip = eth.data
        ips_n[i] = int.from_bytes(ip.src,"little")
        protocol_n[i] = ip.p
        total_length_n[i] = ip.len
        
        if ip.p == 6:
            tcp_packet += 1
            TCP=ip.data 
            dst_port_n[i] = TCP.dport
            src_port_n[i] = TCP.sport
        elif ip.p == 17:
            udp_packet += 1
            UDP=ip.data
            dst_port_n[i] = UDP.dport
            src_port_n[i] = UDP.sport
            udp_length_n[i] = UDP.ulen
        else:
            dst_port_n[i] = 0
            src_port_n[i] = 0
    else:
        other += 1
        
    i += 1

input.close()
print("total # of packets: %s"  % (total_packet))
print("# of UDP packets: %s" % (udp_packet))
print("# of TCP packets: %s" % (tcp_packet))
print("# of other packets except for TCP or UDP: %s"  % (other))

end = time.time()
print(end - start)
# Out:
# total # of packets: 152733
# # of UDP packets: 152733
# # of TCP packets: 0
# # of other packets except for TCP or UDP: 0
# 2.1693918704986572

# %% [markdown]
# ### Get attack keys of DDoS attacks containing only UDP traffic

# %%
path_to_json = 'signatures/'
json_files = [pos_json for pos_json in os.listdir(path_to_json) if pos_json.endswith('.json')]

udp_keys=[]

for jf in json_files:
    with open('signatures/' + jf) as f:
        data=json.load(f)
    protocol = data.get("protocol")

    if protocol != "TCP" and protocol != "HTTP" and protocol != "ICMP":
        udp_keys.append(jf[:-5])

print("# of UDP DDoS attacks: ", len(udp_keys))
# Out:
# # of UDP DDoS attacks:  253

# %% [markdown]
# ### Get AMI score and other stats per UDP DDoS Attack

# %%
start = time.time()

counter = 1
most_important_features = []

#iterate over all attack keys with UDP attacks
for attack_key in udp_keys:
    try:
        input = open('attack_pcaps/' + attack_key + '.pcap', 'rb')
        attack = dpkt.pcap.Reader(input)

        udp_packet = 0
        tcp_packet = 0
        other = 0
        total_packet = 0
        i = 0
        
        ############### 
        #loop trough packets to get the number of packets in the attack
        #############
        for ts, buf in attack:
            eth = dpkt.ethernet.Ethernet(buf)
            total_packet += 1 

        input.close()
        
        #######################
        #initialize numpy arrays for all the to measure features
        ##############################
        ips_a = np.empty(total_packet)
        protocol_a = np.empty(total_packet)
        total_length_a = np.empty(total_packet)
        src_port_a = np.empty(total_packet)
        dst_port_a = np.empty(total_packet)
        udp_length_a = np.empty(total_packet)
        labels_a = np.ones(total_packet)    
        
        ###############
        #loop trough packets and gather features
        #########
        input = open('attack_pcaps/' + attack_key + '.pcap', 'rb')
        attack = dpkt.pcap.Reader(input)
        i = 0
        for ts, buf in attack:
            eth = dpkt.ethernet.Ethernet(buf)
            if eth.type == 2048:
                ip = eth.data
                ips_a[i] = int.from_bytes(ip.src,"little")
                protocol_a[i] = ip.p
                total_length_a[i] = ip.len
                if ip.p == 6:
                    tcp_packet += 1
                    TCP=ip.data 
                    dst_port_a[i] = TCP.dport
                    src_port_a[i] = TCP.sport
                elif ip.p == 17:
                    udp_packet += 1
                    UDP=ip.data
                    try:
                        udp_length_a[i] = UDP.ulen
                        dst_port_a[i] = UDP.dport
                        src_port_a[i] = UDP.sport
                    except:
                        udp_length_a[i] = UDP.ulen
                        dst_port_a[i] = UDP.dport
                        src_port_a[i] = UDP.sport
                else:
                    other += 1
                    dst_port_a[i] = 0
                    src_port_a[i] = 0
            else:
                other += 1

            i += 1
            
        ###############
        #make Numpy arrays with attack features and normal features together
        ################
        ips = np.append(ips_a, ips_n)
        protocol = np.append(protocol_a, protocol_n)
        total_length = np.append(total_length_a, total_length_n)
        src_port = np.append(src_port_a, src_port_n)
        dst_port = np.append(dst_port_a, dst_port_n)
        udp_length = np.append(udp_length_a, udp_length_n)
        labels = np.append(labels_a, labels_n)

        features = [ips,protocol,total_length,src_port,dst_port,udp_length]

        ##########
        #Calculate adjusted mutual information score
        ############
        scores = []
        for x in features:
            score = adjusted_mutual_info_score(np.repeat(x,4), np.repeat(labels,4), "arithmetic")
            scores.append(score)
            
        ###########
        #Print all stats per attack
        #######
        print("attackkey: ", attack_key)
        print("total # of packets: %s"  % (total_packet))
        print("# of UDP packets: %s" % (udp_packet))
        print("# of TCP packets: %s" % (tcp_packet))
        print("# of other packets except for TCP or UDP: %s"  % (other))
        print("Features: ips,protocol,total_length,src_port,dst_port,udp_length")
        print("AMI scores: ", scores)
                
        numpy.unique(total_length)
        
        fname = "signatures/" + attack_key + ".json"
        with open(fname) as jsonfile:
            sig = json.load(jsonfile)
        sig['AMI'] = scores
        with open(fname, mode='w') as f:
            f.write(json.dumps(sig, indent=2))
        
        max_index, max_value = max(enumerate(scores), key=operator.itemgetter(1))
        most_important_features.append(max_index)
        print("Most important feature: ", max_index)
        end = time.time()
        print(end - start)
        print(counter,"/",len(udp_keys))
        counter += 1
        print("#####################################")
    except Exception as e:
        print("something went wrong with attack ", attack_key)
        print(str(e))
print(end - start)
# Out:
# attackkey:  a43a626aff8968889e14096fcdc5e1f5
# total # of packets: 182836
# # of UDP packets: 182836
# # of TCP packets: 0
# # of other packets except for TCP or UDP: 0
# Features: ips,protocol,total_length,src_port,dst_port,udp_length
# AMI scores:  [0.32804197845782124, 2.4166171588213676e-15, 0.5457104444959394, 0.5212409165991726, 0.5117158798018506, 0.545733562057418]
# Most important feature:  5
# 8.7776198387146
# 1 / 253
# #####################################
# attackkey:  dce5ef87684753c1c5588f1197ac59f6
# total # of packets: 18259
# # of UDP packets: 18259
# # of TCP packets: 0
# # of other packets except for TCP or UDP: 0
# Features: ips,protocol,total_length,src_port,dst_port,udp_length
# AMI scores:  [0.16103044626432686, 9.39522067887482e-15, 0.21394613954999, 0.19084951316012302, 0.20732361141108954, 0.21396049758791405]
# Most important feature:  5
# 11.285322666168213
# 2 / 253
# #####################################
# attackkey:  3bc4411e6ad43580551f36a9fffc1347
# total # of packets: 2
# # of UDP packets: 2
# # of TCP packets: 0
# # of other packets except for TCP or UDP: 0
# Features: ips,protocol,total_length,src_port,dst_port,udp_length
# AMI scores:  [7.612429097709338e-05, 0.0, 9.526109185639655e-05, 9.409189464890851e-05, 9.776512584925293e-05, 9.527257174165251e-05]
# Most important feature:  4
# 12.390186071395874
# 3 / 253
# #####################################
# attackkey:  c2c0ae9c5b744fc888fc6ef94584d67f
# total # of packets: 7311
# # of UDP packets: 7311
# # of TCP packets: 0
# # of other packets except for TCP or UDP: 0
# Features: ips,protocol,total_length,src_port,dst_port,udp_length
# AMI scores:  [0.09448332348524044, 0.0, 0.1053023689226959, 0.10184725642457636, 0.09979968740602667, 0.10531083757318371]
# Most important feature:  5
# 14.250239849090576
# 4 / 253
# #####################################
# attackkey:  13a3abc6486457ee99c72ce73eb456bd
# total # of packets: 3
# # of UDP packets: 3
# # of TCP packets: 0
# # of other packets except for TCP or UDP: 0
# Features: ips,protocol,total_length,src_port,dst_port,udp_length
# AMI scores:  [0.00011305154527387256, 4.583746133227516e-11, 0.00014390587750115016, 0.0001517197822860791, 0.0001438781324274639, 0.00014392317211591422]
# Most important feature:  3
# 15.322288274765015
# 5 / 253
# #####################################
# attackkey:  ebfe0afeea7f5417f340782d8a4d6f83
# total # of packets: 6292
# # of UDP packets: 6292
# # of TCP packets: 0
# # of other packets except for TCP or UDP: 0
# Features: ips,protocol,total_length,src_port,dst_port,udp_length
# AMI scores:  [0.08319925462533656, 2.04963944025092e-14, 0.11817900348553989, 0.11000909025600325, 0.09593496004606517, 0.11818864235729573]
# Most important feature:  5
# 16.983031272888184
# 6 / 253
# #####################################
# attackkey:  abdc10fabdb343768c96dc3e3d30372a
# total # of packets: 698
# # of UDP packets: 698
# # of TCP packets: 0
# # of other packets except for TCP or UDP: 0
# Features: ips,protocol,total_length,src_port,dst_port,udp_length
# AMI scores:  [0.015810873978738923, 3.6448323623732013e-13, 0.019393839691743547, 0.020230688331114542, 0.018874985596093866, 0.019395623447916836]
# Most important feature:  3
# 18.229052543640137
# 7 / 253
# #####################################
# attackkey:  448676cc26e220f1eb40b2fabd1888cf
# total # of packets: 353
# # of UDP packets: 353
# # of TCP packets: 0
# # of other packets except for TCP or UDP: 0
# Features: ips,protocol,total_length,src_port,dst_port,udp_length
# AMI scores:  [0.008916620379993601, 1.643191632559113e-15, 0.01204798368185385, 0.011388843694429265, 0.010933887388474624, 0.012049159505066617]
# Most important feature:  5
# 19.385080099105835
# 8 / 253
# #####################################
# attackkey:  7ff63ada8c94b8d6064aa26f7e9efbac
# total # of packets: 185
# # of UDP packets: 185
# # of TCP packets: 0
# # of other packets except for TCP or UDP: 0
# Features: ips,protocol,total_length,src_port,dst_port,udp_length
# AMI scores:  [0.005097510740782585, 0.0, 0.006186015380238095, 0.006523599180233942, 0.006191696223831867, 0.00618667576821315]
# Most important feature:  3
# 20.508822679519653
# 9 / 253
# #####################################
# attackkey:  9c0d8554ae6c7f77a0da512bc8deb21b
# total # of packets: 23361
# # of UDP packets: 23361
# # of TCP packets: 0
# # of other packets except for TCP or UDP: 0
# Features: ips,protocol,total_length,src_port,dst_port,udp_length
# AMI scores:  [0.1822760990395792, 4.3282807229861455e-15, 0.23521025534435175, 0.2208194495846763, 0.1598280145028793, 0.23522474759877351]
# Most important feature:  5
# 23.099101066589355
# 10 / 253
# #####################################
# attackkey:  be5e53797846dd305fd8c450c3ce1021_4
# total # of packets: 86814
# # of UDP packets: 86814
# # of TCP packets: 0
# # of other packets except for TCP or UDP: 0
# Features: ips,protocol,total_length,src_port,dst_port,udp_length
# AMI scores:  [0.22710457516841803, 8.275203704173351e-15, 0.4320890897119571, 0.42452003618092754, 0.38486965256124983, 0.4323500016074783]
# Most important feature:  5
# 28.018082857131958
# 11 / 253
# #####################################
# attackkey:  62d0da3c450842f40da8ae4b0c32d345
# total # of packets: 23329
# # of UDP packets: 23329
# # of TCP packets: 0
# # of other packets except for TCP or UDP: 0
# Features: ips,protocol,total_length,src_port,dst_port,udp_length
# AMI scores:  [0.1811476136227648, 7.877042581919495e-15, 0.2448130320675966, 0.22064670193269692, 0.23684339753936193, 0.244828683581516]
# Most important feature:  5
# 30.469146013259888
# 12 / 253
# #####################################
# attackkey:  86bf22271e530d57313cc3c4d2e73c9d
# total # of packets: 421
# # of UDP packets: 421
# # of TCP packets: 0
# # of other packets except for TCP or UDP: 0
# Features: ips,protocol,total_length,src_port,dst_port,udp_length
# AMI scores:  [0.010341266315149507, 0.0, 0.012250883409817993, 0.01323096194512961, 0.012417517628227147, 0.012252059576860205]
# Most important feature:  3
# 31.631555557250977
# 13 / 253
# #####################################
# attackkey:  07b54769cadc2fb05f0467775d13925c_3
# total # of packets: 8
# # of UDP packets: 8
# # of TCP packets: 0
# # of other packets except for TCP or UDP: 0
# Features: ips,protocol,total_length,src_port,dst_port,udp_length
# AMI scores:  [0.00029057256191004324, -6.2483243833916365e-12, 0.00038217843377178965, 0.00036941468375230763, 0.00036317456816925943, 0.00038222412506693035]
# Most important feature:  5
# 32.67659640312195
# 14 / 253
# #####################################
# attackkey:  9b87222053c383934c1347e45f383701
# total # of packets: 356
# # of UDP packets: 356
# # of TCP packets: 0
# # of other packets except for TCP or UDP: 0
# Features: ips,protocol,total_length,src_port,dst_port,udp_length
# AMI scores:  [0.008966206732296953, 2.1541622016095764e-13, 0.010691631465787412, 0.011471407373510755, 0.010825552763172585, 0.010692678780877422]
# Most important feature:  3
# 33.830759048461914
# 15 / 253
# #####################################
# attackkey:  a8f13befb53acd25aec1c3f92b1ee02b
# total # of packets: 1792
# # of UDP packets: 1792
# # of TCP packets: 0
# # of other packets except for TCP or UDP: 0
# Features: ips,protocol,total_length,src_port,dst_port,udp_length
# AMI scores:  [0.033766937575647214, -1.9620426068238044e-15, 0.04676339031417063, 0.04341211743250499, 0.040341264529199825, 0.04676756448025383]
# Most important feature:  5
# 35.17434477806091
# 16 / 253
# #####################################
# attackkey:  1c2317dbc0d5fdb64c5796844050591e
# total # of packets: 182
# # of UDP packets: 182
# # of TCP packets: 0
# # of other packets except for TCP or UDP: 0
# Features: ips,protocol,total_length,src_port,dst_port,udp_length
# AMI scores:  [0.005031085830215085, 1.1566613583935849e-12, 0.005837645412508541, 0.006307308478769764, 0.0061712665802861446, 0.0058382729874375235]
# Most important feature:  3
# 36.329126596450806
# 17 / 253
# #####################################
# attackkey:  1d114fcbaccdd54b5a60d353087f88b6
# total # of packets: 36193
# # of UDP packets: 36193
# # of TCP packets: 0
# # of other packets except for TCP or UDP: 0
# Features: ips,protocol,total_length,src_port,dst_port,udp_length
# AMI scores:  [0.21578704018617398, 1.7668155595671513e-14, 0.2899971475799467, 0.2788242272843914, 0.29410250681912137, 0.29001358066255756]
# Most important feature:  4
# 39.332321882247925
# 18 / 253
# #####################################
# attackkey:  d9103c17cf563a8a40d3ec0dfff0fcb7
# total # of packets: 2
# # of UDP packets: 2
# # of TCP packets: 0
# # of other packets except for TCP or UDP: 0
# Features: ips,protocol,total_length,src_port,dst_port,udp_length
# AMI scores:  [7.612455518798831e-05, 0.0, 0.00011545251753201336, 0.00010310237659723094, 9.776512584925292e-05, 0.00011546590977849658]
# Most important feature:  5
# 40.338133811950684
# 19 / 253
# #####################################
# attackkey:  95120088fead57b6620bba06ee0ba5ca
# total # of packets: 170
# # of UDP packets: 170
# # of TCP packets: 0
# # of other packets except for TCP or UDP: 0
# Features: ips,protocol,total_length,src_port,dst_port,udp_length
# AMI scores:  [0.0047366852357821985, 1.2272552635563947e-12, 0.0055106668513872385, 0.006060160852004992, 0.0057218160020911105, 0.0055112646219592516]
# Most important feature:  3
# 41.452938079833984
# 20 / 253
# #####################################
# attackkey:  68387e4ccd91c2f0a78bd8050165b33a
# total # of packets: 106
# # of UDP packets: 106
# # of TCP packets: 0
# # of other packets except for TCP or UDP: 0
# Features: ips,protocol,total_length,src_port,dst_port,udp_length
# AMI scores:  [0.0031262318950289864, 3.023270100609267e-16, 0.0035460912858169148, 0.004003494117569772, 0.003801094634059248, 0.003546497874512349]
# Most important feature:  3
# 42.55676054954529
# 21 / 253
# #####################################
# attackkey:  b0e94727d740256be0aa28ac8ccdc5d4
# total # of packets: 1071
# # of UDP packets: 1071
# # of TCP packets: 0
# # of other packets except for TCP or UDP: 0
# Features: ips,protocol,total_length,src_port,dst_port,udp_length
# AMI scores:  [0.022564011361664506, -1.5256542917118511e-15, 0.03017414671618932, 0.02872823906667719, 0.027300014902293827, 0.030176874390674204]
# Most important feature:  5
# 43.820234060287476
# 22 / 253
# #####################################
# attackkey:  2bf238448118adaa7dc3695830b084af
# total # of packets: 325
# # of UDP packets: 325
# # of TCP packets: 0
# # of other packets except for TCP or UDP: 0
# Features: ips,protocol,total_length,src_port,dst_port,udp_length
# AMI scores:  [0.008292968096656498, 0.0, 0.010389530882825074, 0.010611996596292514, 0.01001420796777553, 0.010390558273794896]
# Most important feature:  3
# 44.97041320800781
# 23 / 253
# #####################################
# attackkey:  9138ab0055963f033fd015cea2ef1bc6
# total # of packets: 343
# # of UDP packets: 343
# # of TCP packets: 0
# # of other packets except for TCP or UDP: 0
# Features: ips,protocol,total_length,src_port,dst_port,udp_length
# AMI scores:  [0.008693403790725975, -4.3616898723708793e-16, 0.010937318023727325, 0.01111271033289334, 0.010512999474658813, 0.01093839228377975]
# Most important feature:  3
# 46.12148714065552
# 24 / 253
# #####################################
# attackkey:  ff23e4055ca26ec6b05177d71fdfbcda
# total # of packets: 4570
# # of UDP packets: 4570
# # of TCP packets: 0
# # of other packets except for TCP or UDP: 0
# Features: ips,protocol,total_length,src_port,dst_port,udp_length
# AMI scores:  [0.06793175188343036, 0.0, 0.0832551610224342, 0.08771110625226675, 0.08376126524063708, 0.0832620471809684]
# Most important feature:  3
# 47.66447377204895
# 25 / 253
# #####################################
# attackkey:  03ff3b06a5ce77f630b06e2e3983ac7d
# total # of packets: 3
# # of UDP packets: 3
# # of TCP packets: 0
# # of other packets except for TCP or UDP: 0
# Features: ips,protocol,total_length,src_port,dst_port,udp_length
# AMI scores:  [0.00011305154527387258, 4.583746133227516e-11, 0.00014390587750115016, 0.0001517197822860791, 0.0001438781324274639, 0.00014392317211591422]
# Most important feature:  3
# 48.69254231452942
# 26 / 253
# #####################################
# attackkey:  9ae4af2b74c64e5243e5ef791c9894ff
# total # of packets: 523
# # of UDP packets: 523
# # of TCP packets: 0
# # of other packets except for TCP or UDP: 0
# Features: ips,protocol,total_length,src_port,dst_port,udp_length
# AMI scores:  [0.01242196302982235, -6.089087475725221e-16, 0.014561076493713573, 0.015892611679172993, 0.014909468462862221, 0.014562443791289691]
# Most important feature:  3
# 49.88551449775696
# 27 / 253
# #####################################
# attackkey:  2e10fe671e45a71cfbab9092ff6beea1
# total # of packets: 9818
# # of UDP packets: 9818
# # of TCP packets: 0
# # of other packets except for TCP or UDP: 0
# Features: ips,protocol,total_length,src_port,dst_port,udp_length
# AMI scores:  [0.11356795442817229, 4.4851075073322496e-14, 0.15557307822973684, 0.12644706633560382, 0.11598845552154496, 0.15558503017426717]
# Most important feature:  5
# 51.798940896987915
# 28 / 253
# #####################################
# attackkey:  4c853fcff01b06cd9571173df0ddfdae
# total # of packets: 2
# # of UDP packets: 2
# # of TCP packets: 0
# # of other packets except for TCP or UDP: 0
# Features: ips,protocol,total_length,src_port,dst_port,udp_length
# AMI scores:  [7.612429097709338e-05, 0.0, 9.526109185639655e-05, 0.00010310237659723094, 9.776512584925293e-05, 9.527257174165251e-05]
# Most important feature:  3
# 52.83136343955994
# 29 / 253
# #####################################
# attackkey:  3b501f660da8235c7f13c92c7a6e501b_2
# total # of packets: 6
# # of UDP packets: 6
# # of TCP packets: 0
# # of other packets except for TCP or UDP: 0
# Features: ips,protocol,total_length,src_port,dst_port,udp_length
# AMI scores:  [0.000220746748846859, 2.4344118966798492e-11, 0.00028791902301359107, 0.0002919200236257679, 0.0002771866459303597, 0.0002879534961665906]
# Most important feature:  3
# 53.87353467941284
# 30 / 253
# #####################################
# attackkey:  327c4fea908ad500186f3b281ffd9c85
# total # of packets: 917
# # of UDP packets: 917
# # of TCP packets: 0
# # of other packets except for TCP or UDP: 0
# Features: ips,protocol,total_length,src_port,dst_port,udp_length
# AMI scores:  [0.019798416556141316, 1.7314209158798334e-15, 0.024847552146684073, 0.025341055723728852, 0.0235901928371557, 0.024849812488279624]
# Most important feature:  3
# 55.12130260467529
# 31 / 253
# #####################################
# attackkey:  cc8a3617866a4ad112ac2e7315a92e3d
# total # of packets: 123
# # of UDP packets: 123
# # of TCP packets: 0
# # of other packets except for TCP or UDP: 0
# Features: ips,protocol,total_length,src_port,dst_port,udp_length
# AMI scores:  [0.00356502754118706, -2.653396695061785e-16, 0.003919458538700234, 0.004564154881552469, 0.004333214941995761, 0.003919903821707667]
# Most important feature:  3
# 56.2345712184906
# 32 / 253
# #####################################
# attackkey:  45efbd82e475f6ec51928fbeb00aab86
# total # of packets: 38935
# # of UDP packets: 38935
# # of TCP packets: 0
# # of other packets except for TCP or UDP: 0
# Features: ips,protocol,total_length,src_port,dst_port,udp_length
# AMI scores:  [0.21917402706329855, -1.3198045135248217e-15, 0.29629640083173037, 0.2889437864951235, 0.17470292687589284, 0.2963128745560043]
# Most important feature:  5
# 59.57577180862427
# 33 / 253
# #####################################
# attackkey:  01dd938e512bd560020dee459a32a5d5
# total # of packets: 20004
# # of UDP packets: 20004
# # of TCP packets: 0
# # of other packets except for TCP or UDP: 0
# Features: ips,protocol,total_length,src_port,dst_port,udp_length
# AMI scores:  [0.16799241964871825, 0.0, 0.22328230278454161, 0.201688000131864, 0.15304139874809486, 0.2232968156221427]
# Most important feature:  5
# 62.55515670776367
# 34 / 253
# #####################################
# attackkey:  6c94d9829f082c1d8174d6086d840667
# total # of packets: 434
# # of UDP packets: 434
# # of TCP packets: 0
# # of other packets except for TCP or UDP: 0
# Features: ips,protocol,total_length,src_port,dst_port,udp_length
# AMI scores:  [0.01061372746773048, -3.5672740609456147e-16, 0.013459382705632785, 0.013576568054312751, 0.012777099135982564, 0.013460668777050306]
# Most important feature:  3
# 63.76743984222412
# 35 / 253
# #####################################
# attackkey:  bf0d6dd9cc4e2914a0403eadc58e4973
# total # of packets: 323
# # of UDP packets: 323
# # of TCP packets: 0
# # of other packets except for TCP or UDP: 0
# Features: ips,protocol,total_length,src_port,dst_port,udp_length
# AMI scores:  [0.008251691244451558, 4.592340748118894e-16, 0.010178670959022657, 0.010556061906933601, 0.009880489193756043, 0.010179679011273169]
# Most important feature:  3
# 64.93060064315796
# 36 / 253
# #####################################
# attackkey:  d8ecc4556c6300355248ce2df77c49d3
# total # of packets: 370
# # of UDP packets: 370
# # of TCP packets: 0
# # of other packets except for TCP or UDP: 0
# Features: ips,protocol,total_length,src_port,dst_port,udp_length
# AMI scores:  [0.009282042635801513, -2.043846200980861e-16, 0.009730077591537883, 0.011855057860630062, 0.011210066851671951, 0.009731032427159647]
# Most important feature:  3
# 66.11167073249817
# 37 / 253
# #####################################
# attackkey:  da27a3365d19888db6a6e3be0b29e669
# total # of packets: 544
# # of UDP packets: 544
# # of TCP packets: 0
# # of other packets except for TCP or UDP: 0
# Features: ips,protocol,total_length,src_port,dst_port,udp_length
# AMI scores:  [0.012839614927554852, 1.4962982640940657e-13, 0.015725710347998915, 0.016427343596577958, 0.015415058669390564, 0.015727180948097864]
# Most important feature:  3
# 67.32504963874817
# 38 / 253
# #####################################
# attackkey:  e6c3668c7cd00f4b287b6fc92a0afcb9
# total # of packets: 319
# # of UDP packets: 319
# # of TCP packets: 0
# # of other packets except for TCP or UDP: 0
# Features: ips,protocol,total_length,src_port,dst_port,udp_length
# AMI scores:  [0.008168936358077167, 7.117474725007162e-13, 0.010208246371887325, 0.010444008460021506, 0.009869985129128976, 0.010209258671937756]
# Most important feature:  3
# 68.48605513572693
# 39 / 253
# #####################################
# attackkey:  368726a5d6fdb862413347cd6a8e8bed
# total # of packets: 24620
# # of UDP packets: 24620
# # of TCP packets: 0
# # of other packets except for TCP or UDP: 0
# Features: ips,protocol,total_length,src_port,dst_port,udp_length
# AMI scores:  [0.17321287135014538, 0.0, 0.1531690251043026, 0.2509346101697392, 0.24357496804844153, 0.1532128807770421]
# Most important feature:  3
# 71.78578400611877
# 40 / 253
# #####################################
# attackkey:  8a327818e8786fe1d94ff545c7d4ce7e
# total # of packets: 19
# # of UDP packets: 19
# # of TCP packets: 0
# # of other packets except for TCP or UDP: 0
# Features: ips,protocol,total_length,src_port,dst_port,udp_length
# AMI scores:  [0.0006561636232786471, 0.0, 0.0008809775738192137, 0.000851543536176976, 0.0008116565044267293, 0.0008810821689566693]
# Most important feature:  5
# 72.82440614700317
# 41 / 253
# #####################################
# attackkey:  79c0560b679610429eb83424c59852fc
# total # of packets: 8
# # of UDP packets: 8
# # of TCP packets: 0
# # of other packets except for TCP or UDP: 0
# Features: ips,protocol,total_length,src_port,dst_port,udp_length
# AMI scores:  [0.0002905725619100433, -6.2483243833916365e-12, 0.00014634969818396772, 0.00038215389426998335, 0.00036317456816925943, 0.0001463730632482749]
# Most important feature:  3
# 73.8599603176117
# 42 / 253
# #####################################
# attackkey:  a78ea8f55a89331897f7b8c016ec7c56_3
# total # of packets: 4
# # of UDP packets: 4
# # of TCP packets: 0
# # of other packets except for TCP or UDP: 0
# Features: ips,protocol,total_length,src_port,dst_port,udp_length
# AMI scores:  [0.0001494115039413955, 3.523433499126527e-11, 0.000192262957511155, 0.00019924963539462464, 0.00018902542284419483, 0.0001922860255760757]
# Most important feature:  3
# 74.89080595970154
# 43 / 253
# #####################################
# attackkey:  736a858075f927f6b316047f10eda62b
# total # of packets: 1731
# # of UDP packets: 1731
# # of TCP packets: 0
# # of other packets except for TCP or UDP: 0
# Features: ips,protocol,total_length,src_port,dst_port,udp_length
# AMI scores:  [0.033139020527650526, 0.0, 0.040022775903117404, 0.04224543586556374, 0.040634301207080954, 0.040028797885788614]
# Most important feature:  3
# 76.33573460578918
# 44 / 253
# #####################################
# attackkey:  73051c1f4ac17cef173632b9d2e26ecc
# total # of packets: 2
# # of UDP packets: 2
# # of TCP packets: 0
# # of other packets except for TCP or UDP: 0
# Features: ips,protocol,total_length,src_port,dst_port,udp_length
# AMI scores:  [7.612429097709338e-05, 0.0, 9.526109185639655e-05, 0.00010310237659723094, 9.776512584925293e-05, 9.527257174165251e-05]
# Most important feature:  3
# 77.46269631385803
# 45 / 253
# #####################################
# attackkey:  d0ccb10c7e08ac2d4a16804d53b30845
# total # of packets: 1375
# # of UDP packets: 1375
# # of TCP packets: 0
# # of other packets except for TCP or UDP: 0
# Features: ips,protocol,total_length,src_port,dst_port,udp_length
# AMI scores:  [0.027497334518704956, 6.906426749534542e-14, 0.03331994170292166, 0.03479861682050073, 0.03383443721210407, 0.033322923618539675]
# Most important feature:  3
# 79.03179836273193
# 46 / 253
# #####################################
# attackkey:  473d2481db15f5d783405db702ed72e7
# total # of packets: 1319
# # of UDP packets: 1319
# # of TCP packets: 0
# # of other packets except for TCP or UDP: 0
# Features: ips,protocol,total_length,src_port,dst_port,udp_length
# AMI scores:  [0.026529907672501886, 5.631741538164573e-16, 0.036502081003602145, 0.03403346341878329, 0.03183276176857378, 0.036505369167780556]
# Most important feature:  5
# 80.52238082885742
# 47 / 253
# #####################################
# attackkey:  ae87f4dbbd8c4ccc941995ff673e29b0
# total # of packets: 494
# # of UDP packets: 494
# # of TCP packets: 0
# # of other packets except for TCP or UDP: 0
# Features: ips,protocol,total_length,src_port,dst_port,udp_length
# AMI scores:  [0.0118361376847887, 4.89241319709741e-13, 0.014253671690405747, 0.015147074842576139, 0.014225361294022472, 0.0142550173236614]
# Most important feature:  3
# 81.72719049453735
# 48 / 253
# #####################################
# attackkey:  7f2b2ef41a396bbd0269a4801fd84274
# total # of packets: 308
# # of UDP packets: 308
# # of TCP packets: 0
# # of other packets except for TCP or UDP: 0
# Features: ips,protocol,total_length,src_port,dst_port,udp_length
# AMI scores:  [0.00791536267755652, 7.33085602733043e-13, 0.008780240712892939, 0.010134574599658339, 0.009686249433609543, 0.008781122117096635]
# Most important feature:  3
# 82.89196443557739
# 49 / 253
# #####################################
# attackkey:  a3bbaba745fbded23fc3217df906cff5
# total # of packets: 101
# # of UDP packets: 101
# # of TCP packets: 0
# # of other packets except for TCP or UDP: 0
# Features: ips,protocol,total_length,src_port,dst_port,udp_length
# AMI scores:  [0.0029941482964178858, 1.4847310467128408e-15, 0.0032453010300591265, 0.003836238131423122, 0.0036103491945845357, 0.0032456779444050175]
# Most important feature:  3
# 83.99434733390808
# 50 / 253
# #####################################
# attackkey:  d99f6d570c052b54911cd2cc894cbbe3
# total # of packets: 47140
# # of UDP packets: 47140
# # of TCP packets: 0
# # of other packets except for TCP or UDP: 0
# Features: ips,protocol,total_length,src_port,dst_port,udp_length
# AMI scores:  [0.23384170046839836, 4.69381822683619e-15, 0.3069765649689614, 0.31582843066524746, 0.17715128395853008, 0.3069922987659942]
# Most important feature:  3
# 89.32007884979248
# 51 / 253
# #####################################
# attackkey:  f2724bf2d516c91e8373f7153a595ff1_5
# total # of packets: 86089
# # of UDP packets: 86089
# # of TCP packets: 0
# # of other packets except for TCP or UDP: 0
# Features: ips,protocol,total_length,src_port,dst_port,udp_length
# AMI scores:  [0.2264011326288054, 1.8682327546519407e-15, 0.42762807161181077, 0.42336461145441634, 0.3891721121773251, 0.42791741756737317]
# Most important feature:  5
# 94.15903401374817
# 52 / 253
# #####################################
# attackkey:  00631e77cb5c08e9d5e7673a73bcd887
# total # of packets: 123
# # of UDP packets: 123
# # of TCP packets: 0
# # of other packets except for TCP or UDP: 0
# Features: ips,protocol,total_length,src_port,dst_port,udp_length
# AMI scores:  [0.0035633460983553367, -2.653396695061785e-16, 0.004004102112231152, 0.004564154881552469, 0.004303524797580013, 0.004004555253944771]
# Most important feature:  3
# 95.26592373847961
# 53 / 253
# #####################################
# attackkey:  2ea180355c6612d69993431075783e86
# total # of packets: 153
# # of UDP packets: 153
# # of TCP packets: 0
# # of other packets except for TCP or UDP: 0
# Features: ips,protocol,total_length,src_port,dst_port,udp_length
# AMI scores:  [0.004319244507161743, 0.0, 0.005062109286943288, 0.005527241278397546, 0.005226905955493438, 0.005062664821909646]
# Most important feature:  3
# 96.38459157943726
# 54 / 253
# #####################################
# attackkey:  b31fef7a664bc7101a0754852a977026
# total # of packets: 491
# # of UDP packets: 491
# # of TCP packets: 0
# # of other packets except for TCP or UDP: 0
# Features: ips,protocol,total_length,src_port,dst_port,udp_length
# AMI scores:  [0.01177910801922074, 3.2119741934460375e-16, 0.015165764773677924, 0.015069465082749561, 0.014129539062948627, 0.015167195264899506]
# Most important feature:  5
# 97.57614803314209
# 55 / 253
# #####################################
# attackkey:  e3f7f0f4245f803d9458a9a882bd1816
# total # of packets: 41968
# # of UDP packets: 41968
# # of TCP packets: 0
# # of other packets except for TCP or UDP: 0
# Features: ips,protocol,total_length,src_port,dst_port,udp_length
# AMI scores:  [0.25913920229355725, -4.4294967713748115e-15, 0.34636276938915284, 0.32268106689042736, 0.31430500768546593, 0.34638402709301064]
# Most important feature:  5
# 100.69331622123718
# 56 / 253
# #####################################
# attackkey:  20bb770b6cc349185770a35cbeda3956
# total # of packets: 8
# # of UDP packets: 8
# # of TCP packets: 0
# # of other packets except for TCP or UDP: 0
# Features: ips,protocol,total_length,src_port,dst_port,udp_length
# AMI scores:  [0.0002905725619100433, -6.2483243833916365e-12, 0.00038217843377178965, 0.0003821668372818057, 0.00036317456816925943, 0.00038222412506693035]
# Most important feature:  5
# 101.73777770996094
# 57 / 253
# #####################################
# attackkey:  1fe0c0580a97bc027388276a7a9e0137
# total # of packets: 3
# # of UDP packets: 3
# # of TCP packets: 0
# # of other packets except for TCP or UDP: 0
# Features: ips,protocol,total_length,src_port,dst_port,udp_length
# AMI scores:  [0.00011305154527387258, 4.583746133227516e-11, 0.00014390587750115016, 0.00015171978228607912, 0.0001438781324274639, 0.00014392317211591422]
# Most important feature:  3
# 102.77652049064636
# 58 / 253
# #####################################
# attackkey:  6850a3840f24fbe3f3990b2b0a09e0a4
# total # of packets: 2
# # of UDP packets: 2
# # of TCP packets: 0
# # of other packets except for TCP or UDP: 0
# Features: ips,protocol,total_length,src_port,dst_port,udp_length
# AMI scores:  [7.612429097709338e-05, 0.0, 9.526109185639655e-05, 0.00010310237659723094, 9.776512584925293e-05, 9.527257174165251e-05]
# Most important feature:  3
# 103.80424189567566
# 59 / 253
# #####################################
# attackkey:  7321dc7d0fa7d9f4855d59f90406bd18
# total # of packets: 15302
# # of UDP packets: 15302
# # of TCP packets: 0
# # of other packets except for TCP or UDP: 0
# Features: ips,protocol,total_length,src_port,dst_port,udp_length
# AMI scores:  [0.14828018277331584, 1.0556444743263225e-14, 0.1925046019209077, 0.17081736318722063, 0.18736957247222663, 0.19251767925188287]
# Most important feature:  5
# 105.90968155860901
# 60 / 253
# #####################################
# attackkey:  c08cba0ed075092ab6dde234d3f1f93e
# total # of packets: 2
# # of UDP packets: 2
# # of TCP packets: 0
# # of other packets except for TCP or UDP: 0
# Features: ips,protocol,total_length,src_port,dst_port,udp_length
# AMI scores:  [7.612429097709338e-05, 0.0, 9.526109185639655e-05, 0.00010310237659723094, 9.776512584925293e-05, 9.527257174165251e-05]
# Most important feature:  3
# 106.93934631347656
# 61 / 253
# #####################################
# attackkey:  a0bf8deaa640bfe5018eebf1cba426e2
# total # of packets: 13758
# # of UDP packets: 13758
# # of TCP packets: 0
# # of other packets except for TCP or UDP: 0
# Features: ips,protocol,total_length,src_port,dst_port,udp_length
# AMI scores:  [0.1386746250491199, 3.3370466892054854e-14, 0.17499164039744614, 0.15939021360158526, 0.17593771110790066, 0.1750036100985446]
# Most important feature:  4
# 108.95308685302734
# 62 / 253
# #####################################
# attackkey:  974dc23908b40cd3c28be24e053de886
# total # of packets: 280
# # of UDP packets: 280
# # of TCP packets: 0
# # of other packets except for TCP or UDP: 0
# Features: ips,protocol,total_length,src_port,dst_port,udp_length
# AMI scores:  [0.007308298653755319, -7.961231232547978e-13, 0.007244845896968431, 0.005570285673717165, 0.008935304032764204, 0.007245589840367675]
# Most important feature:  4
# 110.09215950965881
# 63 / 253
# #####################################
# attackkey:  740fa950731369d92dafa370dd254efe_2
# total # of packets: 13
# # of UDP packets: 13
# # of TCP packets: 0
# # of other packets except for TCP or UDP: 0
# Features: ips,protocol,total_length,src_port,dst_port,udp_length
# AMI scores:  [0.0004600599291083312, 4.024454443950935e-12, 0.0006125392968665361, 0.0006002013022256737, 0.000571290888288647, 0.0006126122995726831]
# Most important feature:  5
# 111.13895630836487
# 64 / 253
# #####################################
# attackkey:  946f30995594fceed5ce8b597917ffa7
# total # of packets: 28703
# # of UDP packets: 28703
# # of TCP packets: 0
# # of other packets except for TCP or UDP: 0
# Features: ips,protocol,total_length,src_port,dst_port,udp_length
# AMI scores:  [0.19294633677024595, 3.845416474452432e-15, 0.26557530369960536, 0.24745263440207768, 0.2075410394379453, 0.2655917528513754]
# Most important feature:  5
# 113.81706094741821
# 65 / 253
# #####################################
# attackkey:  634eba16476dc1a99beecafc6689bd87
# total # of packets: 133
# # of UDP packets: 133
# # of TCP packets: 0
# # of other packets except for TCP or UDP: 0
# Features: ips,protocol,total_length,src_port,dst_port,udp_length
# AMI scores:  [0.003818257517845377, 1.5210944268819828e-12, 0.0051815478078909, 0.004804044652649299, 0.004606710358660421, 0.00518211315069468]
# Most important feature:  5
# 114.928151845932
# 66 / 253
# #####################################
# attackkey:  0539e6100beb380efd42766a5d8623df
# total # of packets: 19325
# # of UDP packets: 19325
# # of TCP packets: 0
# # of other packets except for TCP or UDP: 0
# Features: ips,protocol,total_length,src_port,dst_port,udp_length
# AMI scores:  [0.16820101827462386, 1.238365411709413e-14, 0.22227179652178003, 0.1975496028934304, 0.15124721259101886, 0.22228652660836906]
# Most important feature:  5
# 117.33208870887756
# 67 / 253
# #####################################
# attackkey:  392f3f9d394ec1bc0326cece6057f22b
# total # of packets: 2
# # of UDP packets: 2
# # of TCP packets: 0
# # of other packets except for TCP or UDP: 0
# Features: ips,protocol,total_length,src_port,dst_port,udp_length
# AMI scores:  [7.612429097709338e-05, 0.0, 9.526109185639655e-05, 0.00010310237659723094, 9.776512584925293e-05, 9.527257174165251e-05]
# Most important feature:  3
# 118.3591992855072
# 68 / 253
# #####################################
# attackkey:  e4a71e543f7edc305fbbbd545c215f81
# total # of packets: 2142
# # of UDP packets: 2142
# # of TCP packets: 0
# # of other packets except for TCP or UDP: 0
# Features: ips,protocol,total_length,src_port,dst_port,udp_length
# AMI scores:  [0.03911171772430424, 1.4602460338668616e-13, 0.05571657827184825, 0.038263027153946944, 0.04512466389029564, 0.05572154898851857]
# Most important feature:  5
# 119.76793146133423
# 69 / 253
# #####################################
# attackkey:  1275d75edb74854d9fa0e13325f253a6
# total # of packets: 36445
# # of UDP packets: 36445
# # of TCP packets: 0
# # of other packets except for TCP or UDP: 0
# Features: ips,protocol,total_length,src_port,dst_port,udp_length
# AMI scores:  [0.21772156860371158, 5.7771997900935e-15, 0.2904467232611799, 0.279781457711027, 0.17358858422068899, 0.29046313816757585]
# Most important feature:  5
# 123.16344404220581
# 70 / 253
# #####################################
# attackkey:  d73d0246981dde6351ef6e9d3085dab5
# total # of packets: 908
# # of UDP packets: 908
# # of TCP packets: 0
# # of other packets except for TCP or UDP: 0
# Features: ips,protocol,total_length,src_port,dst_port,udp_length
# AMI scores:  [0.01955225262898378, 0.0, 0.022523309583928168, 0.02513696755557156, 0.023752568630289118, 0.022525359234225485]
# Most important feature:  3
# 124.50287437438965
# 71 / 253
# #####################################
# attackkey:  f17db0d141a535c1b18d70cbfe13a6a5
# total # of packets: 668
# # of UDP packets: 668
# # of TCP packets: 0
# # of other packets except for TCP or UDP: 0
# Features: ips,protocol,total_length,src_port,dst_port,udp_length
# AMI scores:  [0.015246102752482954, 3.7922375180129394e-13, 0.01877657310435422, 0.019504890085221407, 0.01818651815483918, 0.018778303893255608]
# Most important feature:  3
# 125.73081731796265
# 72 / 253
# #####################################
# attackkey:  35b310bf1cae16a5f37ae483b74a200f
# total # of packets: 3
# # of UDP packets: 3
# # of TCP packets: 0
# # of other packets except for TCP or UDP: 0
# Features: ips,protocol,total_length,src_port,dst_port,udp_length
# AMI scores:  [0.00011305154527387256, 4.583746133227516e-11, 0.00014390587750115016, 0.0001517197822860791, 0.0001438781324274639, 0.00014392317211591422]
# Most important feature:  3
# 126.76422572135925
# 73 / 253
# #####################################
# attackkey:  97cf1b96a7cbe3dd19d6d5baa70db1cd
# total # of packets: 30555
# # of UDP packets: 30555
# # of TCP packets: 0
# # of other packets except for TCP or UDP: 0
# Features: ips,protocol,total_length,src_port,dst_port,udp_length
# AMI scores:  [0.20401779634113434, -3.860482141681956e-15, 0.26206922569924757, 0.25578379256136696, 0.16907607452145024, 0.26208509665542296]
# Most important feature:  5
# 129.70892763137817
# 74 / 253
# #####################################
# attackkey:  b4348b2293cf64d074c1248b78f4b27d
# total # of packets: 2594
# # of UDP packets: 2594
# # of TCP packets: 0
# # of other packets except for TCP or UDP: 0
# Features: ips,protocol,total_length,src_port,dst_port,udp_length
# AMI scores:  [0.045120599798430625, 1.2143028675175405e-13, 0.05477347718306615, 0.057619257003227106, 0.05475553315498958, 0.054778238257662634]
# Most important feature:  3
# 131.15994024276733
# 75 / 253
# #####################################
# attackkey:  700062ab3a066e721cc674c40a089795
# total # of packets: 1677
# # of UDP packets: 1677
# # of TCP packets: 0
# # of other packets except for TCP or UDP: 0
# Features: ips,protocol,total_length,src_port,dst_port,udp_length
# AMI scores:  [0.03232311149167387, -1.7510883865939518e-15, 0.04368480137979166, 0.0412027800451178, 0.03872076364030938, 0.04368870095646072]
# Most important feature:  5
# 132.51098370552063
# 76 / 253
# #####################################
# attackkey:  c093f324dc7908241b9be60bb8b58473
# total # of packets: 382
# # of UDP packets: 382
# # of TCP packets: 0
# # of other packets except for TCP or UDP: 0
# Features: ips,protocol,total_length,src_port,dst_port,udp_length
# AMI scores:  [0.009521194361481147, 1.413946977458511e-15, 0.011033763923222797, 0.012181795411578135, 0.011469638931586802, 0.011034837080357598]
# Most important feature:  3
# 133.67727160453796
# 77 / 253
# #####################################
# attackkey:  4a0140eeb1c0047de2984220cbd5ef7e
# total # of packets: 9
# # of UDP packets: 9
# # of TCP packets: 0
# # of other packets except for TCP or UDP: 0
# Features: ips,protocol,total_length,src_port,dst_port,udp_length
# AMI scores:  [0.00032501795862385346, 1.684217092053513e-11, 0.0003904788474010124, 0.0003887252720282161, 0.0004055082006827987, 0.00039052645180324974]
# Most important feature:  4
# 134.738543510437
# 78 / 253
# #####################################
# attackkey:  5cc22060a7e9457ee619db0c95efeadd
# total # of packets: 91
# # of UDP packets: 91
# # of TCP packets: 0
# # of other packets except for TCP or UDP: 0
# Features: ips,protocol,total_length,src_port,dst_port,udp_length
# AMI scores:  [0.002729599310964967, -2.124258057319746e-12, 0.002900085487845701, 0.00349818273471534, 0.003317741703707338, 0.0029004267592727287]
# Most important feature:  3
# 135.85349535942078
# 79 / 253
# #####################################
# attackkey:  2e7f29b29b7e038dbf23aa25766a378f
# total # of packets: 61902
# # of UDP packets: 61902
# # of TCP packets: 0
# # of other packets except for TCP or UDP: 0
# Features: ips,protocol,total_length,src_port,dst_port,udp_length
# AMI scores:  [0.19190655675575977, -5.259488287345321e-15, 0.2849222714733028, 0.376027591960029, 0.3683219942669508, 0.28493431772979]
# Most important feature:  3
# 139.8484013080597
# 80 / 253
# #####################################
# attackkey:  7cb73e12f758f85209f233de87c57e5e
# total # of packets: 2
# # of UDP packets: 2
# # of TCP packets: 0
# # of other packets except for TCP or UDP: 0
# Features: ips,protocol,total_length,src_port,dst_port,udp_length
# AMI scores:  [7.612429097709338e-05, 0.0, 9.526109185639655e-05, 9.409189464890851e-05, 9.776512584925293e-05, 9.527257174165251e-05]
# Most important feature:  4
# 140.87945699691772
# 81 / 253
# #####################################
# attackkey:  e4ed2d7237e72181e0185f1d46e022de
# total # of packets: 291
# # of UDP packets: 291
# # of TCP packets: 0
# # of other packets except for TCP or UDP: 0
# Features: ips,protocol,total_length,src_port,dst_port,udp_length
# AMI scores:  [0.007550170844360365, 0.0, 0.009106422618021186, 0.00965252352625253, 0.009108950080537538, 0.009107338593140137]
# Most important feature:  3
# 142.0146358013153
# 82 / 253
# #####################################
# attackkey:  27cfc69ee315e649068abc9fbafb14cd
# total # of packets: 182836
# # of UDP packets: 182836
# # of TCP packets: 0
# # of other packets except for TCP or UDP: 0
# Features: ips,protocol,total_length,src_port,dst_port,udp_length
# AMI scores:  [0.32804197845782124, 2.4166171588213676e-15, 0.5457104444959394, 0.5212409165991726, 0.5117158798018506, 0.545733562057418]
# Most important feature:  5
# 150.3034815788269
# 83 / 253
# #####################################
# attackkey:  7f19b44817e1d16ea99933c6bce54131
# total # of packets: 66618
# # of UDP packets: 66618
# # of TCP packets: 0
# # of other packets except for TCP or UDP: 0
# Features: ips,protocol,total_length,src_port,dst_port,udp_length
# AMI scores:  [0.16167265044565451, 0.0, 0.4126516174331586, 0.1801784361694599, 0.37856030967213306, 0.4118634886988974]
# Most important feature:  2
# 155.39408445358276
# 84 / 253
# #####################################
# attackkey:  999b725c3c1ea70afc1c7df860b41968
# total # of packets: 36524
# # of UDP packets: 36524
# # of TCP packets: 0
# # of other packets except for TCP or UDP: 0
# Features: ips,protocol,total_length,src_port,dst_port,udp_length
# AMI scores:  [0.21502273012353343, 7.242687731870474e-15, 0.28068455472038106, 0.2800803701842013, 0.17358153167674334, 0.2806999995330864]
# Most important feature:  5
# 158.6315987110138
# 85 / 253
# #####################################
# attackkey:  a0fd113a9a21d37b5303d9c93bd505b2
# total # of packets: 13219
# # of UDP packets: 13219
# # of TCP packets: 0
# # of other packets except for TCP or UDP: 0
# Features: ips,protocol,total_length,src_port,dst_port,udp_length
# AMI scores:  [0.1368684463594131, 0.0, 0.17760229665398555, 0.15522344327840537, 0.13245005325613038, 0.17761475329735799]
# Most important feature:  5
# 160.70324182510376
# 86 / 253
# #####################################
# attackkey:  07b54769cadc2fb05f0467775d13925c
# total # of packets: 2
# # of UDP packets: 2
# # of TCP packets: 0
# # of other packets except for TCP or UDP: 0
# Features: ips,protocol,total_length,src_port,dst_port,udp_length
# AMI scores:  [7.612429097709336e-05, 0.0, 9.526109185639655e-05, 9.001944207348191e-05, 9.776512584925293e-05, 9.527257174165251e-05]
# Most important feature:  4
# 161.74047255516052
# 87 / 253
# #####################################
# attackkey:  a7b3506d4d20bf5eff18958737bc025a
# total # of packets: 1081
# # of UDP packets: 1081
# # of TCP packets: 0
# # of other packets except for TCP or UDP: 0
# Features: ips,protocol,total_length,src_port,dst_port,udp_length
# AMI scores:  [0.022582615765166892, 2.513951560356738e-13, 0.030954085062524467, 0.028982166789139317, 0.027094811481240707, 0.030956886878873418]
# Most important feature:  5
# 163.02201628684998
# 88 / 253
# #####################################
# attackkey:  bf6bf159d7237d3dfcb9ff0d68764079
# total # of packets: 245
# # of UDP packets: 245
# # of TCP packets: 0
# # of other packets except for TCP or UDP: 0
# Features: ips,protocol,total_length,src_port,dst_port,udp_length
# AMI scores:  [0.006505572575153799, 1.5382044260428653e-15, 0.007469866111981179, 0.008322830790613425, 0.00788750709753103, 0.007470638600585505]
# Most important feature:  3
# 164.1523633003235
# 89 / 253
# #####################################
# attackkey:  c3ea1742df4569fa778eaab379bd8772
# total # of packets: 360
# # of UDP packets: 360
# # of TCP packets: 0
# # of other packets except for TCP or UDP: 0
# Features: ips,protocol,total_length,src_port,dst_port,udp_length
# AMI scores:  [0.009071126679326306, 4.184661455238946e-16, 0.010764447450154561, 0.011581296864474821, 0.011090676027940657, 0.010765500035489324]
# Most important feature:  3
# 165.29022884368896
# 90 / 253
# #####################################
# attackkey:  c8b2ee81d5d417e9bb9e23d520c477ee
# total # of packets: 634
# # of UDP packets: 634
# # of TCP packets: 0
# # of other packets except for TCP or UDP: 0
# Features: ips,protocol,total_length,src_port,dst_port,udp_length
# AMI scores:  [0.014634253755934294, 1.335241883680795e-13, 0.01921880614528435, 0.01863975417615, 0.017805231354103963, 0.019220580705656704]
# Most important feature:  5
# 166.49958658218384
# 91 / 253
# #####################################
# attackkey:  e9500bc4af5548ba856451a23466073e
# total # of packets: 7394
# # of UDP packets: 7394
# # of TCP packets: 0
# # of other packets except for TCP or UDP: 0
# Features: ips,protocol,total_length,src_port,dst_port,udp_length
# AMI scores:  [0.09431715174447744, 1.72083942546809e-14, 0.13611753028135626, 0.12272166113834812, 0.11846092142659595, 0.1361286676277124]
# Most important feature:  5
# 168.16909432411194
# 92 / 253
# #####################################
# attackkey:  a048351d1f46ebf12a5835c0f61f4635
# total # of packets: 4
# # of UDP packets: 4
# # of TCP packets: 0
# # of other packets except for TCP or UDP: 0
# Features: ips,protocol,total_length,src_port,dst_port,udp_length
# AMI scores:  [0.0001494115039413955, 3.523433499126527e-11, 0.000192262957511155, 0.00019924963539462467, 0.00018902542284419483, 0.0001922860255760757]
# Most important feature:  3
# 169.192884683609
# 93 / 253
# #####################################
# attackkey:  14dd8e6fdcecd5d02573af4ae38f2449
# total # of packets: 13422
# # of UDP packets: 13422
# # of TCP packets: 0
# # of other packets except for TCP or UDP: 0
# Features: ips,protocol,total_length,src_port,dst_port,udp_length
# AMI scores:  [0.13778648026716972, 3.395106006625635e-14, 0.17503852019441474, 0.15680409708624335, 0.1331433501383501, 0.17505106826406613]
# Most important feature:  5
# 171.27180433273315
# 94 / 253
# #####################################
# attackkey:  9805c4aa14103ea03aa57bb35cd1a0d5
# total # of packets: 2
# # of UDP packets: 2
# # of TCP packets: 0
# # of other packets except for TCP or UDP: 0
# Features: ips,protocol,total_length,src_port,dst_port,udp_length
# AMI scores:  [7.612429097709338e-05, 0.0, 9.526109185639655e-05, 3.983486658902074e-05, 9.776512584925293e-05, 9.527257174165251e-05]
# Most important feature:  4
# 172.2989764213562
# 95 / 253
# #####################################
# attackkey:  324fe87b957724e969ef1e3893ea67b6
# total # of packets: 7612
# # of UDP packets: 7612
# # of TCP packets: 0
# # of other packets except for TCP or UDP: 0
# Features: ips,protocol,total_length,src_port,dst_port,udp_length
# AMI scores:  [0.09635995076117039, -2.6378691576640308e-15, 0.13854239580306174, 0.12509474945338078, 0.12079363851008294, 0.1385536946358393]
# Most important feature:  5
# 173.9954912662506
# 96 / 253
# #####################################
# attackkey:  565f16c101f6e26f25cbdc0f0258e04b
# total # of packets: 311
# # of UDP packets: 311
# # of TCP packets: 0
# # of other packets except for TCP or UDP: 0
# Features: ips,protocol,total_length,src_port,dst_port,udp_length
# AMI scores:  [0.007989386909482499, 7.274106302616801e-13, 0.009233670712182946, 0.010219155081111818, 0.009636279005334585, 0.009234593678097517]
# Most important feature:  3
# 175.1315369606018
# 97 / 253
# #####################################
# attackkey:  9c436570b69e98e36fcff55f51b7db02
# total # of packets: 290
# # of UDP packets: 290
# # of TCP packets: 0
# # of other packets except for TCP or UDP: 0
# Features: ips,protocol,total_length,src_port,dst_port,udp_length
# AMI scores:  [0.00751739197001488, 7.708825182558016e-13, 0.007986781154288225, 0.009624018124414487, 0.009213777615481623, 0.007987592735028682]
# Most important feature:  3
# 176.28980922698975
# 98 / 253
# #####################################
# attackkey:  d5fc48e54ce98252f2c748728c34a25a
# total # of packets: 510
# # of UDP packets: 510
# # of TCP packets: 0
# # of other packets except for TCP or UDP: 0
# Features: ips,protocol,total_length,src_port,dst_port,udp_length
# AMI scores:  [0.012161651134134697, -4.767419053690027e-13, 0.015530149561406543, 0.015559444592875584, 0.014598211255673782, 0.015531610000164373]
# Most important feature:  3
# 177.46989011764526
# 99 / 253
# #####################################
# attackkey:  9a0c14fc67a9e8a7c03dd118dc088395
# total # of packets: 363
# # of UDP packets: 363
# # of TCP packets: 0
# # of other packets except for TCP or UDP: 0
# Features: ips,protocol,total_length,src_port,dst_port,udp_length
# AMI scores:  [0.00913592152651015, 6.383184839258351e-13, 0.01185349844268927, 0.011663568698561185, 0.011072176600317098, 0.0118546521583223]
# Most important feature:  5
# 178.62246966362
# 100 / 253
# #####################################
# attackkey:  60799e823b0704562c763b07c4df5a55
# total # of packets: 9
# # of UDP packets: 9
# # of TCP packets: 0
# # of other packets except for TCP or UDP: 0
# Features: ips,protocol,total_length,src_port,dst_port,udp_length
# AMI scores:  [0.0003250056942272331, 1.684217092053513e-11, 0.00016611570629055202, 0.00042654322552627386, 0.0004055082006827987, 0.0001661420715163258]
# Most important feature:  3
# 179.6548089981079
# 101 / 253
# #####################################
# attackkey:  020e498be5f87867d753a300e48b6eb3
# total # of packets: 45
# # of UDP packets: 45
# # of TCP packets: 0
# # of other packets except for TCP or UDP: 0
# Features: ips,protocol,total_length,src_port,dst_port,udp_length
# AMI scores:  [0.001449579301627178, 3.9624895511418745e-12, 0.001429636076685074, 0.0018651819546107256, 0.0017658012860676635, 0.0014298146833073289]
# Most important feature:  3
# 180.72851395606995
# 102 / 253
# #####################################
# attackkey:  07047eb879829a0f00ba03fa1425a2ae
# total # of packets: 371
# # of UDP packets: 371
# # of TCP packets: 0
# # of other packets except for TCP or UDP: 0
# Features: ips,protocol,total_length,src_port,dst_port,udp_length
# AMI scores:  [0.00928783761362904, 2.0809353189989597e-13, 0.010956305555818138, 0.011882359287819803, 0.011158954958442617, 0.010957374070569004]
# Most important feature:  3
# 181.87809896469116
# 103 / 253
# #####################################
# attackkey:  63e9b2bc8caf6dd5c6daddee5c55696a
# total # of packets: 2
# # of UDP packets: 2
# # of TCP packets: 0
# # of other packets except for TCP or UDP: 0
# Features: ips,protocol,total_length,src_port,dst_port,udp_length
# AMI scores:  [7.612429097709338e-05, 0.0, 9.526109185639655e-05, 0.00010310237659723094, 9.776512584925293e-05, 9.527257174165251e-05]
# Most important feature:  3
# 182.90697741508484
# 104 / 253
# #####################################
# attackkey:  02a0fea41cbc325869736aa24a81b3d2
# total # of packets: 2
# # of UDP packets: 2
# # of TCP packets: 0
# # of other packets except for TCP or UDP: 0
# Features: ips,protocol,total_length,src_port,dst_port,udp_length
# AMI scores:  [7.612429097709336e-05, 0.0, 9.526109185639655e-05, 0.00010310237659723094, 9.776512584925293e-05, 9.527257174165251e-05]
# Most important feature:  3
# 183.93648982048035
# 105 / 253
# #####################################
# attackkey:  33bd295fd9249d26cd64cabb2a38b01b
# total # of packets: 130
# # of UDP packets: 130
# # of TCP packets: 0
# # of other packets except for TCP or UDP: 0
# Features: ips,protocol,total_length,src_port,dst_port,udp_length
# ...
# total # of packets: 2
# # of UDP packets: 2
# # of TCP packets: 0
# # of other packets except for TCP or UDP: 0
# Features: ips,protocol,total_length,src_port,dst_port,udp_length
# AMI scores:  [7.612429097709338e-05, 0.0, 9.526109185639655e-05, 0.00010310237659723094, 9.776512584925293e-05, 9.527257174165251e-05]
# Most important feature:  3
# 392.8830955028534
# 219 / 253
# #####################################
# attackkey:  8b5cc78cf89aaa128cfcac63f49d008d
# total # of packets: 18835
# # of UDP packets: 18835
# # of TCP packets: 0
# # of other packets except for TCP or UDP: 0
# Features: ips,protocol,total_length,src_port,dst_port,udp_length
# AMI scores:  [0.15295225892477546, 1.0186022135513649e-14, 0.1992076608578882, 0.21744444016336442, 0.2098973780805208, 0.1992204932411085]
# Most important feature:  3
# 395.10332679748535
# 220 / 253
# #####################################
# attackkey:  13073741f538935aa8adfe90bad2ed52
# total # of packets: 8
# # of UDP packets: 8
# # of TCP packets: 0
# # of other packets except for TCP or UDP: 0
# Features: ips,protocol,total_length,src_port,dst_port,udp_length
# AMI scores:  [0.0002905725619100433, -6.2483243833916365e-12, 0.00014634969818396772, 0.0003756157311691188, 0.0003631745681692594, 0.0001463730632482749]
# Most important feature:  3
# 396.2286305427551
# 221 / 253
# #####################################
# attackkey:  19655b0e20c74dcffa056a78cde7ee0f
# total # of packets: 20726
# # of UDP packets: 20726
# # of TCP packets: 0
# # of other packets except for TCP or UDP: 0
# Features: ips,protocol,total_length,src_port,dst_port,udp_length
# AMI scores:  [0.15428344518535858, -2.5594523239840367e-14, 0.2152262683955371, 0.20598383568048625, 0.16620650949512647, 0.21733645384965347]
# Most important feature:  5
# 398.70028281211853
# 222 / 253
# #####################################
# attackkey:  35b310bf1cae16a5f37ae483b74a200f_3
# total # of packets: 4
# # of UDP packets: 4
# # of TCP packets: 0
# # of other packets except for TCP or UDP: 0
# Features: ips,protocol,total_length,src_port,dst_port,udp_length
# AMI scores:  [0.00014941150394139554, 3.523433499126527e-11, 0.000192262957511155, 0.00019924963539462464, 0.00018902542284419483, 0.0001922860255760757]
# Most important feature:  3
# 399.83848786354065
# 223 / 253
# #####################################
# attackkey:  26d9ccb748258b7ffced4190fdaf32ad
# total # of packets: 722
# # of UDP packets: 722
# # of TCP packets: 0
# # of other packets except for TCP or UDP: 0
# Features: ips,protocol,total_length,src_port,dst_port,udp_length
# AMI scores:  [0.01621044831678678, 3.528476823222362e-13, 0.018353860370473596, 0.020806493184918805, 0.019712759542669496, 0.018355544053655855]
# Most important feature:  3
# 401.1479799747467
# 224 / 253
# #####################################
# attackkey:  2242e98304700fc8c938ab9df1924763
# total # of packets: 4
# # of UDP packets: 4
# # of TCP packets: 0
# # of other packets except for TCP or UDP: 0
# Features: ips,protocol,total_length,src_port,dst_port,udp_length
# AMI scores:  [0.00014941150394139549, 3.523433499126527e-11, 8.580977459404891e-05, 0.0001992462918706348, 0.00014075433925358875, 8.582276157149175e-05]
# Most important feature:  3
# 402.2783155441284
# 225 / 253
# #####################################
# attackkey:  a877a80fc3e21a6f001c4d2f514ed993
# total # of packets: 128132
# # of UDP packets: 128132
# # of TCP packets: 0
# # of other packets except for TCP or UDP: 0
# Features: ips,protocol,total_length,src_port,dst_port,udp_length
# AMI scores:  [0.144831168345584, -7.11855669049695e-15, 0.5030432252965233, 0.16477536546708887, 0.4672188299724921, 0.5023469759950909]
# Most important feature:  2
# 411.10612177848816
# 226 / 253
# #####################################
# attackkey:  6c860f9e8c14a471d0a2977d4fde72fe
# total # of packets: 2
# # of UDP packets: 2
# # of TCP packets: 0
# # of other packets except for TCP or UDP: 0
# Features: ips,protocol,total_length,src_port,dst_port,udp_length
# AMI scores:  [7.612429097709338e-05, 0.0, 9.526109185639655e-05, 9.409189464890852e-05, 9.776512584925293e-05, 9.527257174165251e-05]
# Most important feature:  4
# 412.1667332649231
# 227 / 253
# #####################################
# attackkey:  079c27d54c337110c12ae61ea3efe580
# total # of packets: 176
# # of UDP packets: 176
# # of TCP packets: 0
# # of other packets except for TCP or UDP: 0
# Features: ips,protocol,total_length,src_port,dst_port,udp_length
# AMI scores:  [0.004882659448307112, -1.9405423938635947e-16, 0.005518143500554982, 0.006246267024263329, 0.005948310759051495, 0.005518741673929008]
# Most important feature:  3
# 413.2881305217743
# 228 / 253
# #####################################
# attackkey:  577d365326ded44f30f381baf53a0d85
# total # of packets: 18
# # of UDP packets: 18
# # of TCP packets: 0
# # of other packets except for TCP or UDP: 0
# Features: ips,protocol,total_length,src_port,dst_port,udp_length
# AMI scores:  [0.0006240130946951621, 0.0, 0.0007846491352927167, 0.0007611989112084849, 0.0007721753315220295, 0.0007847436160493305]
# Most important feature:  5
# 414.34947872161865
# 229 / 253
# #####################################
# attackkey:  a11ba565a01155351afe6d433594d238
# total # of packets: 3790
# # of UDP packets: 3790
# # of TCP packets: 0
# # of other packets except for TCP or UDP: 0
# Features: ips,protocol,total_length,src_port,dst_port,udp_length
# AMI scores:  [0.05869443827659405, 0.0, 0.08288467056200897, 0.07674831978221221, 0.06898968768854534, 0.08289176119143216]
# Most important feature:  5
# 415.86582350730896
# 230 / 253
# #####################################
# attackkey:  55e711623f86622365194f1ee1fb9a7e
# total # of packets: 53
# # of UDP packets: 53
# # of TCP packets: 0
# # of other packets except for TCP or UDP: 0
# Features: ips,protocol,total_length,src_port,dst_port,udp_length
# AMI scores:  [0.0016811000633179252, -2.7886455857758555e-16, 0.0017179115730296365, 0.0021606156537647006, 0.0020403622835902125, 0.0017181228340218152]
# Most important feature:  3
# 416.9496178627014
# 231 / 253
# #####################################
# attackkey:  3e04da1987736f143f2a69ca98ac95cc
# total # of packets: 179
# # of UDP packets: 179
# # of TCP packets: 0
# # of other packets except for TCP or UDP: 0
# Features: ips,protocol,total_length,src_port,dst_port,udp_length
# AMI scores:  [0.004953641184347925, 3.9114373894123436e-13, 0.0052655928409190735, 0.006338950768391168, 0.006002927458855988, 0.00526616720000382]
# Most important feature:  3
# 418.0755090713501
# 232 / 253
# #####################################
# attackkey:  bd9cb3b69f02c8fdba7efc5bb8a6a4db
# total # of packets: 379
# # of UDP packets: 379
# # of TCP packets: 0
# # of other packets except for TCP or UDP: 0
# Features: ips,protocol,total_length,src_port,dst_port,udp_length
# AMI scores:  [0.009447812454696936, 2.0433178509094067e-13, 0.009900742734416148, 0.01210028973942634, 0.011546598602658364, 0.009901711196270263]
# Most important feature:  3
# 419.23525071144104
# 233 / 253
# #####################################
# attackkey:  d3d5d8c57ffd4dd8bbf51cdf0f46e5ef
# total # of packets: 842
# # of UDP packets: 842
# # of TCP packets: 0
# # of other packets except for TCP or UDP: 0
# Features: ips,protocol,total_length,src_port,dst_port,udp_length
# AMI scores:  [0.01848516061783338, 3.116135774104373e-13, 0.021430856365263137, 0.023625626833782727, 0.022328820713827118, 0.021432809173469302]
# Most important feature:  3
# 420.4786956310272
# 234 / 253
# #####################################
# attackkey:  26dd1cc577105e675089fba903fdcfe5
# total # of packets: 182836
# # of UDP packets: 182836
# # of TCP packets: 0
# # of other packets except for TCP or UDP: 0
# Features: ips,protocol,total_length,src_port,dst_port,udp_length
# AMI scores:  [0.32804197845782124, 2.4166171588213676e-15, 0.5457104444959394, 0.5212409165991726, 0.5117158798018506, 0.545733562057418]
# Most important feature:  5
# 428.78243255615234
# 235 / 253
# #####################################
# attackkey:  5b8fe3b9db4812ccdba94672810cde76
# total # of packets: 142
# # of UDP packets: 142
# # of TCP packets: 0
# # of other packets except for TCP or UDP: 0
# Features: ips,protocol,total_length,src_port,dst_port,udp_length
# AMI scores:  [0.004046254352266969, 4.785306933930593e-13, 0.004612899845461944, 0.005060176045802477, 0.004945147959570083, 0.004613412360315269]
# Most important feature:  3
# 429.90355110168457
# 236 / 253
# #####################################
# attackkey:  41fd4b0156a33263722ee03c74e238a4
# total # of packets: 13483
# # of UDP packets: 13483
# # of TCP packets: 0
# # of other packets except for TCP or UDP: 0
# Features: ips,protocol,total_length,src_port,dst_port,udp_length
# AMI scores:  [0.13819965407654314, 0.0, 0.1851358374923184, 0.15727637148503146, 0.17381851905884685, 0.1851492188250748]
# Most important feature:  5
# 431.88227891921997
# 237 / 253
# #####################################
# attackkey:  6c20366b62b47d0ccf5baf0973ac2dcd
# total # of packets: 31557
# # of UDP packets: 31557
# # of TCP packets: 0
# # of other packets except for TCP or UDP: 0
# Features: ips,protocol,total_length,src_port,dst_port,udp_length
# AMI scores:  [0.20317718288849318, -1.4549491140505162e-15, 0.2614848649463376, 0.2601227481994456, 0.16977044960642043, 0.2614998212881763]
# Most important feature:  5
# 434.890664100647
# 238 / 253
# #####################################
# attackkey:  03c18359ae35b93a3657b5971fd952fa
# total # of packets: 295
# # of UDP packets: 295
# # of TCP packets: 0
# # of other packets except for TCP or UDP: 0
# Features: ips,protocol,total_length,src_port,dst_port,udp_length
# AMI scores:  [0.007637804595017677, 2.5393386792286606e-13, 0.009848924300284017, 0.009766376775888992, 0.009314646021536001, 0.009849908151508971]
# Most important feature:  5
# 436.0433373451233
# 239 / 253
# #####################################
# attackkey:  ad0ba2fa0338aaa18aefe31edb295d09
# total # of packets: 2060
# # of UDP packets: 2060
# # of TCP packets: 0
# # of other packets except for TCP or UDP: 0
# Features: ips,protocol,total_length,src_port,dst_port,udp_length
# AMI scores:  [0.03803732596116569, -1.9262998456335032e-15, 0.05405690189684963, 0.036963852256847285, 0.0440422416806919, 0.05406173171059493]
# Most important feature:  5
# 437.4670889377594
# 240 / 253
# #####################################
# attackkey:  a3644f57a18ccb958a3d64f96e943828
# total # of packets: 306
# # of UDP packets: 306
# # of TCP packets: 0
# # of other packets except for TCP or UDP: 0
# Features: ips,protocol,total_length,src_port,dst_port,udp_length
# AMI scores:  [0.007879747646078187, 7.374486425232559e-13, 0.009241547050010183, 0.010078107642296195, 0.009525294880859386, 0.009242471946216345]
# Most important feature:  3
# 438.7560272216797
# 241 / 253
# #####################################
# attackkey:  967a3709db351926be99ddc0f7d4697a
# total # of packets: 681
# # of UDP packets: 681
# # of TCP packets: 0
# # of other packets except for TCP or UDP: 0
# Features: ips,protocol,total_length,src_port,dst_port,udp_length
# AMI scores:  [0.015501244594714494, -2.4367108534375903e-16, 0.017702573596698228, 0.019820242198163147, 0.01874812023426459, 0.017704201729856418]
# Most important feature:  3
# 440.0017259120941
# 242 / 253
# #####################################
# attackkey:  a45683a1a9df6cedd1cfbcdd4ba3d386
# total # of packets: 8
# # of UDP packets: 8
# # of TCP packets: 0
# # of other packets except for TCP or UDP: 0
# Features: ips,protocol,total_length,src_port,dst_port,udp_length
# AMI scores:  [0.0002905725619100433, -6.2483243833916365e-12, 0.00014634969818396772, 0.00038215389426998335, 0.00036317456816925943, 0.0001463730632482749]
# Most important feature:  3
# 441.03488755226135
# 243 / 253
# #####################################
# attackkey:  6045eb0742cfeb9721590e44dcb83208
# total # of packets: 132
# # of UDP packets: 132
# # of TCP packets: 0
# # of other packets except for TCP or UDP: 0
# Features: ips,protocol,total_length,src_port,dst_port,udp_length
# AMI scores:  [0.0037941492341994447, 4.988599307430091e-16, 0.0051538287704211575, 0.0047718928708901575, 0.004575803927541576, 0.005154391395282623]
# Most important feature:  5
# 442.1522603034973
# 244 / 253
# #####################################
# attackkey:  e1a41a64f56779841448b722ad95cbbf
# total # of packets: 347
# # of UDP packets: 347
# # of TCP packets: 0
# # of other packets except for TCP or UDP: 0
# Features: ips,protocol,total_length,src_port,dst_port,udp_length
# AMI scores:  [0.00877218373620328, 1.8661360060959794e-15, 0.01093982057891796, 0.011223335101504089, 0.010525139851716363, 0.010940893640343284]
# Most important feature:  3
# 443.31429743766785
# 245 / 253
# #####################################
# attackkey:  55b5c5e6e9f50ad9adbd206f6d51d091
# total # of packets: 2
# # of UDP packets: 2
# # of TCP packets: 0
# # of other packets except for TCP or UDP: 0
# Features: ips,protocol,total_length,src_port,dst_port,udp_length
# AMI scores:  [7.612429097709338e-05, 0.0, 9.526109185639655e-05, 4.7691038744169136e-05, 9.776512584925293e-05, 9.527257174165251e-05]
# Most important feature:  4
# 444.3636441230774
# 246 / 253
# #####################################
# attackkey:  7af2ab2522bc7757eb6c448a6498f576
# total # of packets: 87525
# # of UDP packets: 87525
# # of TCP packets: 0
# # of other packets except for TCP or UDP: 0
# Features: ips,protocol,total_length,src_port,dst_port,udp_length
# AMI scores:  [0.3326706258887584, 5.8088339773365005e-15, 0.45411084094898885, 0.42573643533999167, 0.41429186574529403, 0.4541343184914507]
# Most important feature:  5
# 449.23966121673584
# 247 / 253
# #####################################
# attackkey:  5745d17a8591ba66f264c19a9aa00320
# total # of packets: 267
# # of UDP packets: 267
# # of TCP packets: 0
# # of other packets except for TCP or UDP: 0
# Features: ips,protocol,total_length,src_port,dst_port,udp_length
# AMI scores:  [0.007011625299330738, -2.7048853268848347e-16, 0.00623342420730071, 0.008963601065007118, 0.00840939243264122, 0.0062340771430168095]
# Most important feature:  3
# 450.37749123573303
# 248 / 253
# #####################################
# attackkey:  02a3a3fc266b09b7645e538efbc1ea11
# total # of packets: 560
# # of UDP packets: 560
# # of TCP packets: 0
# # of other packets except for TCP or UDP: 0
# Features: ips,protocol,total_length,src_port,dst_port,udp_length
# AMI scores:  [0.013185839903113852, 4.4031994146075125e-13, 0.01762331680768121, 0.01683197121784764, 0.015960521546514957, 0.017624959300773946]
# Most important feature:  5
# 451.5706024169922
# 249 / 253
# #####################################
# attackkey:  dff11da43816e0bf1620739cd003b51d
# total # of packets: 23541
# # of UDP packets: 23541
# # of TCP packets: 0
# # of other packets except for TCP or UDP: 0
# Features: ips,protocol,total_length,src_port,dst_port,udp_length
# AMI scores:  [0.18178326456233052, 7.837852204964235e-15, 0.2141687262663084, 0.221787939823535, 0.15988029472393533, 0.2141820464289106]
# Most important feature:  3
# 454.19206166267395
# 250 / 253
# #####################################
# attackkey:  85e194d3ed23183769ed40aa93b26038
# total # of packets: 2
# # of UDP packets: 2
# # of TCP packets: 0
# # of other packets except for TCP or UDP: 0
# Features: ips,protocol,total_length,src_port,dst_port,udp_length
# AMI scores:  [7.612429097709336e-05, 0.0, 9.526109185639655e-05, 0.00010310237659723094, 9.776512584925293e-05, 9.527257174165251e-05]
# Most important feature:  3
# 455.2292811870575
# 251 / 253
# #####################################
# attackkey:  609a510cd92b735eebee0accba5396d8
# total # of packets: 5238
# # of UDP packets: 5238
# # of TCP packets: 0
# # of other packets except for TCP or UDP: 0
# Features: ips,protocol,total_length,src_port,dst_port,udp_length
# AMI scores:  [0.07458979059313538, 2.4408248053094422e-14, 0.08974138576609897, 0.09578150103926618, 0.09337489189324194, 0.08974867692017326]
# Most important feature:  3
# 456.82244992256165
# 252 / 253
# #####################################
# attackkey:  3fa2ccc8230dc08b7a4d60d24d8c43f4
# total # of packets: 2
# # of UDP packets: 2
# # of TCP packets: 0
# # of other packets except for TCP or UDP: 0
# Features: ips,protocol,total_length,src_port,dst_port,udp_length
# AMI scores:  [7.612429097709338e-05, 0.0, 9.526109185639655e-05, 0.00010310237659723094, 9.776512584925293e-05, 9.527257174165251e-05]
# Most important feature:  3
# 457.85724329948425
# 253 / 253
# #####################################
# 457.85724329948425

# %% [markdown]
# ### Analysis and Conclusions

# %%
for i in range(0,6):
    print(i,most_important_features.count(i))
# Out:
# 0 0
# 1 0
# 2 2
# 3 144
# 4 13
# 5 94

# %% [markdown]
# The counts of most important feature per feature are: <br/>
#
# 0 IP address: 0 <br/>
# 1 Protocol: 0 <br/>
# 2 Total packet length: 2 <br/>
# 3 UDP source port: 144 <br/>
# 4 Destination port: 13 <br/>
# 5 UDP payload length: 94 <br/>
#
# None of the attacks has its IP address as most important feature. This can be explained by the fact that there are too much different IP addresses. Furthermore by the fact that the values of the IP addresses are laying in between each other for the normal and attack traffic.
#
# The 31 at the protocol is remarkable, since this AMI value should be zero since all packets should be UDP packets. With manual inspection we discovered that some of the attacks are mixed with ICMP packets.
#
# The UDP source port is for most attacks the distinguishing feature. UDP payload second best.
